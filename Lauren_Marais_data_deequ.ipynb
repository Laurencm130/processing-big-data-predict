# %% [markdown]
# <a href="https://colab.research.google.com/github/Laurencm130/processing-big-data-predict/blob/main/Lauren_Marais_data_deequ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Processing Big Data - Deequ Analysis
#
# © Explore Data Science Academy
#
# ## Honour Code
# I {Lauren Marais}, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the [EDSA honour code](https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#     Non-compliance with the honour code constitutes a material breach of contract.
#
#
# ## Context
#
# Having completed manual data quality checks, it should be obvious that the process can become quite cumbersome. As the Data Engineer in the team, you have researched some tools that could potentially save the team from having to do this cumbersome work. In your research, you have come a across a tool called [Deequ](https://github.com/awslabs/deequ), which is a library for measuring the data quality of large datasets.
#
# <div align="center" style="width: 600px; font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://github.com/Explore-AI/Pictures/raw/master/data_engineering/transform/predict/DataQuality.jpg"
#      alt="Data Quality"
#      style="float: center; padding-bottom=0.5em"
#      width=100%/>
#      <p><em>Figure 1. Six dimensions of data quality</em></p>
# </div>
#
# You present this tool to your manager; he is quite impressed and gives you the go-ahead to use this in your implementation. You are now required to perform some data quality tests using this automated data testing tool.

# %%
"""
Colab is essentially running on a linux machine on Google Cloud Platform.
This means that should you want to install something in your notebook you
would have to run headless installs as well as wget. Copying the installs
below will ensure that you have spark and java installed in the environment
as well as available for the notebook.
"""
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.0.0/spark-3.0.0-bin-hadoop2.7.tgz
# !tar xf spark-3.0.0-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
"""
This section helps in rendering your notebook operable and ensuring that
your environment variables for spark are correct. Running this cell in any
notebook allows for any unresolved spark environment to be fixed.
"""
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-bin-hadoop2.7"
os.environ["SPARK_VERSION"] = "3.0.0"

# %%
pip install pyspark==3.0
# Out:
# Requirement already satisfied: pyspark==3.0 in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: py4j==0.10.9 in /usr/local/lib/python3.10/dist-packages (from pyspark==3.0) (0.10.9)

# %%
"""
We need to locate Spark in the system. For that, we import findspark and
use the findspark.init() method. If you want to know the location where
Spark is installed, use findspark.find()
"""
import findspark
findspark.init()
findspark.find()
import pyspark

# %%
"""
This cell is used to import data/files from your local machine to colab
"""
#from google.colab import files
#uploaded = files.upload()
# Out:
# '\nThis cell is used to import data/files from your local machine to colab\n'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/processing-big-data-predict-stocks-data/stocks.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: stocks/1971/08/25/stocks.csv
#   inflating: stocks/1971/08/26/stocks.csv
#   inflating: stocks/1971/08/27/stocks.csv
#   inflating: stocks/1971/08/30/stocks.csv
#   inflating: stocks/1971/08/31/stocks.csv
#   inflating: stocks/1971/09/01/stocks.csv
#   inflating: stocks/1971/09/02/stocks.csv
#   inflating: stocks/1971/09/03/stocks.csv
#   inflating: stocks/1971/09/07/stocks.csv
#   inflating: stocks/1971/09/08/stocks.csv
#   inflating: stocks/1971/09/09/stocks.csv
#   inflating: stocks/1971/09/10/stocks.csv
#   inflating: stocks/1971/09/13/stocks.csv
#   inflating: stocks/1971/09/14/stocks.csv
#   inflating: stocks/1971/09/15/stocks.csv
#   inflating: stocks/1971/09/16/stocks.csv
#   inflating: stocks/1971/09/17/stocks.csv
#   inflating: stocks/1971/09/20/stocks.csv
#   inflating: stocks/1971/09/21/stocks.csv
#   inflating: stocks/1971/09/22/stocks.csv
#   inflating: stocks/1971/09/23/stocks.csv
#   inflating: stocks/1971/09/24/stocks.csv
#   inflating: stocks/1971/09/27/stocks.csv
#   inflating: stocks/1971/09/28/stocks.csv
#   inflating: stocks/1971/09/29/stocks.csv
#   inflating: stocks/1971/09/30/stocks.csv
#   inflating: stocks/1971/10/01/stocks.csv
#   inflating: stocks/1971/10/04/stocks.csv
#   inflating: stocks/1971/10/05/stocks.csv
#   inflating: stocks/1971/10/06/stocks.csv
#   inflating: stocks/1971/10/07/stocks.csv
#   inflating: stocks/1971/10/08/stocks.csv
#   inflating: stocks/1971/10/11/stocks.csv
#   inflating: stocks/1971/10/12/stocks.csv
#   inflating: stocks/1971/10/13/stocks.csv
#   inflating: stocks/1971/10/14/stocks.csv
#   inflating: stocks/1971/10/15/stocks.csv
#   inflating: stocks/1971/10/18/stocks.csv
#   inflating: stocks/1971/10/19/stocks.csv
#   inflating: stocks/1971/10/20/stocks.csv
#   inflating: stocks/1971/10/21/stocks.csv
#   inflating: stocks/1971/10/22/stocks.csv
#   inflating: stocks/1971/10/25/stocks.csv
#   inflating: stocks/1971/10/26/stocks.csv
#   inflating: stocks/1971/10/27/stocks.csv
#   inflating: stocks/1971/10/28/stocks.csv
#   inflating: stocks/1971/10/29/stocks.csv
#   inflating: stocks/1971/11/01/stocks.csv
#   inflating: stocks/1971/11/02/stocks.csv
#   inflating: stocks/1971/11/03/stocks.csv
#   inflating: stocks/1971/11/04/stocks.csv
#   inflating: stocks/1971/11/05/stocks.csv
#   inflating: stocks/1971/11/08/stocks.csv
#   inflating: stocks/1971/11/09/stocks.csv
#   inflating: stocks/1971/11/10/stocks.csv
#   inflating: stocks/1971/11/11/stocks.csv
#   inflating: stocks/1971/11/12/stocks.csv
#   inflating: stocks/1971/11/15/stocks.csv
#   inflating: stocks/1971/11/16/stocks.csv
#   inflating: stocks/1971/11/17/stocks.csv
#   inflating: stocks/1971/11/18/stocks.csv
#   inflating: stocks/1971/11/19/stocks.csv
#   inflating: stocks/1971/11/22/stocks.csv
#   inflating: stocks/1971/11/23/stocks.csv
#   inflating: stocks/1971/11/24/stocks.csv
#   inflating: stocks/1971/11/26/stocks.csv
#   inflating: stocks/1971/11/29/stocks.csv
#   inflating: stocks/1971/11/30/stocks.csv
#   inflating: stocks/1971/12/01/stocks.csv
#   inflating: stocks/1971/12/02/stocks.csv
#   inflating: stocks/1971/12/03/stocks.csv
#   inflating: stocks/1971/12/06/stocks.csv
#   inflating: stocks/1971/12/07/stocks.csv
#   inflating: stocks/1971/12/08/stocks.csv
#   inflating: stocks/1971/12/09/stocks.csv
#   inflating: stocks/1971/12/10/stocks.csv
#   inflating: stocks/1971/12/13/stocks.csv
#   inflating: stocks/1971/12/14/stocks.csv
#   inflating: stocks/1971/12/15/stocks.csv
#   inflating: stocks/1971/12/16/stocks.csv
#   inflating: stocks/1971/12/17/stocks.csv
#   inflating: stocks/1971/12/20/stocks.csv
#   inflating: stocks/1971/12/21/stocks.csv
#   inflating: stocks/1971/12/22/stocks.csv
#   inflating: stocks/1971/12/23/stocks.csv
#   inflating: stocks/1971/12/27/stocks.csv
#   inflating: stocks/1971/12/28/stocks.csv
#   inflating: stocks/1971/12/29/stocks.csv
#   inflating: stocks/1971/12/30/stocks.csv
#   inflating: stocks/1971/12/31/stocks.csv
#   inflating: stocks/1971/01/14/stocks.csv
#   inflating: stocks/1971/01/15/stocks.csv
#   inflating: stocks/1971/01/18/stocks.csv
#   inflating: stocks/1971/01/19/stocks.csv
#   inflating: stocks/1971/01/20/stocks.csv
#   inflating: stocks/1971/01/21/stocks.csv
#   inflating: stocks/1971/01/22/stocks.csv
#   inflating: stocks/1971/01/25/stocks.csv
#   inflating: stocks/1971/01/26/stocks.csv
#   inflating: stocks/1971/01/27/stocks.csv
#   inflating: stocks/1971/01/28/stocks.csv
#   inflating: stocks/1971/01/29/stocks.csv
#   inflating: stocks/1971/01/04/stocks.csv
#   inflating: stocks/1971/01/05/stocks.csv
#   inflating: stocks/1971/01/06/stocks.csv
#   inflating: stocks/1971/01/07/stocks.csv
#   inflating: stocks/1971/01/08/stocks.csv
#   inflating: stocks/1971/01/11/stocks.csv
#   inflating: stocks/1971/01/12/stocks.csv
#   inflating: stocks/1971/01/13/stocks.csv
#   inflating: stocks/1971/02/01/stocks.csv
#   inflating: stocks/1971/02/02/stocks.csv
#   inflating: stocks/1971/02/03/stocks.csv
#   inflating: stocks/1971/02/04/stocks.csv
#   inflating: stocks/1971/02/05/stocks.csv
#   inflating: stocks/1971/02/08/stocks.csv
#   inflating: stocks/1971/02/09/stocks.csv
#   inflating: stocks/1971/02/10/stocks.csv
#   inflating: stocks/1971/02/11/stocks.csv
#   inflating: stocks/1971/02/12/stocks.csv
#   inflating: stocks/1971/02/16/stocks.csv
#   inflating: stocks/1971/02/17/stocks.csv
#   inflating: stocks/1971/02/18/stocks.csv
#   inflating: stocks/1971/02/19/stocks.csv
#   inflating: stocks/1971/02/22/stocks.csv
#   inflating: stocks/1971/02/23/stocks.csv
#   inflating: stocks/1971/02/24/stocks.csv
#   inflating: stocks/1971/02/25/stocks.csv
#   inflating: stocks/1971/02/26/stocks.csv
#   inflating: stocks/1972/02/01/stocks.csv
#   inflating: stocks/1972/02/02/stocks.csv
#   inflating: stocks/1972/02/03/stocks.csv
#   inflating: stocks/1972/02/04/stocks.csv
#   inflating: stocks/1972/02/07/stocks.csv
#   inflating: stocks/1972/02/08/stocks.csv
#   inflating: stocks/1972/02/09/stocks.csv
#   inflating: stocks/1972/02/10/stocks.csv
#   inflating: stocks/1972/02/11/stocks.csv
#   inflating: stocks/1972/02/14/stocks.csv
#   inflating: stocks/1972/02/15/stocks.csv
#   inflating: stocks/1972/02/16/stocks.csv
#   inflating: stocks/1972/02/17/stocks.csv
#   inflating: stocks/1972/02/18/stocks.csv
#   inflating: stocks/1972/02/22/stocks.csv
#   inflating: stocks/1972/02/23/stocks.csv
#   inflating: stocks/1972/02/24/stocks.csv
#   inflating: stocks/1972/02/25/stocks.csv
#   inflating: stocks/1972/02/28/stocks.csv
#   inflating: stocks/1972/02/29/stocks.csv
#   inflating: stocks/1972/03/01/stocks.csv
#   inflating: stocks/1972/03/02/stocks.csv
#   inflating: stocks/1972/03/03/stocks.csv
#   inflating: stocks/1972/03/06/stocks.csv
#   inflating: stocks/1972/03/07/stocks.csv
#   inflating: stocks/1972/03/08/stocks.csv
#   inflating: stocks/1972/03/09/stocks.csv
#   inflating: stocks/1972/03/10/stocks.csv
#   inflating: stocks/1972/03/13/stocks.csv
#   inflating: stocks/1972/03/14/stocks.csv
#   inflating: stocks/1972/03/15/stocks.csv
#   inflating: stocks/1972/03/16/stocks.csv
#   inflating: stocks/1972/03/17/stocks.csv
#   inflating: stocks/1972/03/20/stocks.csv
#   inflating: stocks/1972/03/21/stocks.csv
#   inflating: stocks/1972/03/22/stocks.csv
#   inflating: stocks/1972/03/23/stocks.csv
#   inflating: stocks/1972/03/24/stocks.csv
#   inflating: stocks/1972/03/27/stocks.csv
#   inflating: stocks/1972/03/28/stocks.csv
#   inflating: stocks/1972/03/29/stocks.csv
#   inflating: stocks/1972/03/30/stocks.csv
#   inflating: stocks/1972/04/03/stocks.csv
#   inflating: stocks/1972/04/04/stocks.csv
#   inflating: stocks/1972/04/05/stocks.csv
#   inflating: stocks/1972/04/06/stocks.csv
#   inflating: stocks/1972/04/07/stocks.csv
#   inflating: stocks/1972/04/10/stocks.csv
#   inflating: stocks/1972/04/11/stocks.csv
#   inflating: stocks/1972/04/12/stocks.csv
#   inflating: stocks/1972/04/13/stocks.csv
#   inflating: stocks/1972/04/14/stocks.csv
#   inflating: stocks/1972/04/17/stocks.csv
#   inflating: stocks/1972/04/18/stocks.csv
#   inflating: stocks/1972/04/19/stocks.csv
#   inflating: stocks/1972/04/20/stocks.csv
#   inflating: stocks/1972/04/21/stocks.csv
#   inflating: stocks/1972/04/24/stocks.csv
#   inflating: stocks/1972/04/25/stocks.csv
#   inflating: stocks/1972/04/26/stocks.csv
#   inflating: stocks/1972/04/27/stocks.csv
#   inflating: stocks/1972/04/28/stocks.csv
#   inflating: stocks/1972/05/01/stocks.csv
#   inflating: stocks/1972/05/02/stocks.csv
#   inflating: stocks/1972/05/03/stocks.csv
#   inflating: stocks/1972/05/04/stocks.csv
#   inflating: stocks/1972/05/05/stocks.csv
#   inflating: stocks/1972/05/08/stocks.csv
#   inflating: stocks/1972/05/09/stocks.csv
#   inflating: stocks/1972/05/10/stocks.csv
#   inflating: stocks/1972/05/11/stocks.csv
#   inflating: stocks/1972/05/12/stocks.csv
#   inflating: stocks/1972/05/15/stocks.csv
#   inflating: stocks/1972/05/16/stocks.csv
#   inflating: stocks/1972/05/17/stocks.csv
#   inflating: stocks/1972/05/18/stocks.csv
#   inflating: stocks/1972/05/19/stocks.csv
#   inflating: stocks/1972/05/22/stocks.csv
#   inflating: stocks/1972/05/23/stocks.csv
#   inflating: stocks/1972/05/24/stocks.csv
#   inflating: stocks/1972/05/25/stocks.csv
#   inflating: stocks/1972/05/26/stocks.csv
#   inflating: stocks/1972/05/30/stocks.csv
#   inflating: stocks/1972/05/31/stocks.csv
#   inflating: stocks/1972/06/01/stocks.csv
#   inflating: stocks/1972/06/02/stocks.csv
#   inflating: stocks/1972/06/05/stocks.csv
#   inflating: stocks/1972/06/06/stocks.csv
#   inflating: stocks/1972/06/07/stocks.csv
#   inflating: stocks/1972/06/08/stocks.csv
#   inflating: stocks/1972/06/09/stocks.csv
#   inflating: stocks/1972/06/12/stocks.csv
#   inflating: stocks/1972/06/13/stocks.csv
#   inflating: stocks/1972/06/14/stocks.csv
#   inflating: stocks/1972/06/15/stocks.csv
#   inflating: stocks/1972/06/16/stocks.csv
#   inflating: stocks/1972/06/19/stocks.csv
#   inflating: stocks/1972/06/20/stocks.csv
#   inflating: stocks/1972/06/21/stocks.csv
#   inflating: stocks/1972/06/22/stocks.csv
#   inflating: stocks/1972/06/23/stocks.csv
#   inflating: stocks/1972/06/26/stocks.csv
#   inflating: stocks/1972/06/27/stocks.csv
#   inflating: stocks/1972/06/28/stocks.csv
#   inflating: stocks/1972/06/29/stocks.csv
#   inflating: stocks/1972/06/30/stocks.csv
#   inflating: stocks/1972/07/03/stocks.csv
#   inflating: stocks/1972/07/05/stocks.csv
#   inflating: stocks/1972/07/06/stocks.csv
#   inflating: stocks/1972/07/07/stocks.csv
#   inflating: stocks/1972/07/10/stocks.csv
#   inflating: stocks/1972/07/11/stocks.csv
#   inflating: stocks/1972/07/12/stocks.csv
#   inflating: stocks/1972/07/13/stocks.csv
#   inflating: stocks/1972/07/14/stocks.csv
#   inflating: stocks/1972/07/17/stocks.csv
#   inflating: stocks/1972/07/18/stocks.csv
#   inflating: stocks/1972/07/19/stocks.csv
#   inflating: stocks/1972/07/20/stocks.csv
#   inflating: stocks/1972/07/21/stocks.csv
#   inflating: stocks/1972/07/24/stocks.csv
#   inflating: stocks/1972/07/25/stocks.csv
#   inflating: stocks/1972/07/26/stocks.csv
#   inflating: stocks/1972/07/27/stocks.csv
#   inflating: stocks/1972/07/28/stocks.csv
#   inflating: stocks/1972/07/31/stocks.csv
#   inflating: stocks/1972/08/01/stocks.csv
#   inflating: stocks/1972/08/02/stocks.csv
#   inflating: stocks/1972/08/03/stocks.csv
#   inflating: stocks/1972/08/04/stocks.csv
#   inflating: stocks/1972/08/07/stocks.csv
#   inflating: stocks/1972/08/08/stocks.csv
#   inflating: stocks/1972/08/09/stocks.csv
#   inflating: stocks/1972/08/10/stocks.csv
#   inflating: stocks/1972/08/11/stocks.csv
#   inflating: stocks/1972/08/14/stocks.csv
#   inflating: stocks/1972/08/15/stocks.csv
#   inflating: stocks/1972/08/16/stocks.csv
#   inflating: stocks/1972/08/17/stocks.csv
#   inflating: stocks/1972/08/18/stocks.csv
#   inflating: stocks/1972/08/21/stocks.csv
#   inflating: stocks/1972/08/22/stocks.csv
#   inflating: stocks/1972/08/23/stocks.csv
#   inflating: stocks/1972/08/24/stocks.csv
#   inflating: stocks/1972/08/25/stocks.csv
#   inflating: stocks/1972/08/28/stocks.csv
#   inflating: stocks/1972/08/29/stocks.csv
#   inflating: stocks/1972/08/30/stocks.csv
#   inflating: stocks/1972/08/31/stocks.csv
#   inflating: stocks/1972/09/01/stocks.csv
#   inflating: stocks/1972/09/05/stocks.csv
#   inflating: stocks/1972/09/06/stocks.csv
#   inflating: stocks/1972/09/07/stocks.csv
#   inflating: stocks/1972/09/08/stocks.csv
#   inflating: stocks/1972/09/11/stocks.csv
#   inflating: stocks/1972/09/12/stocks.csv
#   inflating: stocks/1972/09/13/stocks.csv
#   inflating: stocks/1972/09/14/stocks.csv
#   inflating: stocks/1972/09/15/stocks.csv
#   inflating: stocks/1972/09/18/stocks.csv
#   inflating: stocks/1972/09/19/stocks.csv
#   inflating: stocks/1972/09/20/stocks.csv
#   inflating: stocks/1972/09/21/stocks.csv
#   inflating: stocks/1972/09/22/stocks.csv
#   inflating: stocks/1972/09/25/stocks.csv
#   inflating: stocks/1972/09/26/stocks.csv
#   inflating: stocks/1972/09/27/stocks.csv
#   inflating: stocks/1972/09/28/stocks.csv
#   inflating: stocks/1972/09/29/stocks.csv
#   inflating: stocks/1972/10/02/stocks.csv
#   inflating: stocks/1972/10/03/stocks.csv
#   inflating: stocks/1972/10/04/stocks.csv
#   inflating: stocks/1972/10/05/stocks.csv
#   inflating: stocks/1972/10/06/stocks.csv
#   inflating: stocks/1972/10/09/stocks.csv
#   inflating: stocks/1972/10/10/stocks.csv
#   inflating: stocks/1972/10/11/stocks.csv
#   inflating: stocks/1972/10/12/stocks.csv
#   inflating: stocks/1972/10/13/stocks.csv
#   inflating: stocks/1972/10/16/stocks.csv
#   inflating: stocks/1972/10/17/stocks.csv
#   inflating: stocks/1972/10/18/stocks.csv
#   inflating: stocks/1972/10/19/stocks.csv
#   inflating: stocks/1972/10/20/stocks.csv
#   inflating: stocks/1972/10/23/stocks.csv
#   inflating: stocks/1972/10/24/stocks.csv
#   inflating: stocks/1972/10/25/stocks.csv
#   inflating: stocks/1972/10/26/stocks.csv
#   inflating: stocks/1972/10/27/stocks.csv
#   inflating: stocks/1972/10/30/stocks.csv
#   inflating: stocks/1972/10/31/stocks.csv
#   inflating: stocks/1972/11/01/stocks.csv
#   inflating: stocks/1972/11/02/stocks.csv
#   inflating: stocks/1972/11/03/stocks.csv
#   inflating: stocks/1972/11/06/stocks.csv
#   inflating: stocks/1972/11/08/stocks.csv
#   inflating: stocks/1972/11/09/stocks.csv
#   inflating: stocks/1972/11/10/stocks.csv
#   inflating: stocks/1972/11/13/stocks.csv
#   inflating: stocks/1972/11/14/stocks.csv
#   inflating: stocks/1972/11/15/stocks.csv
#   inflating: stocks/1972/11/16/stocks.csv
#   inflating: stocks/1972/11/17/stocks.csv
#   inflating: stocks/1972/11/20/stocks.csv
#   inflating: stocks/1972/11/21/stocks.csv
#   inflating: stocks/1972/11/22/stocks.csv
#   inflating: stocks/1972/11/24/stocks.csv
#   inflating: stocks/1972/11/27/stocks.csv
#   inflating: stocks/1972/11/28/stocks.csv
#   inflating: stocks/1972/11/29/stocks.csv
#   inflating: stocks/1972/11/30/stocks.csv
#   inflating: stocks/1972/12/01/stocks.csv
#   inflating: stocks/1972/12/04/stocks.csv
#   inflating: stocks/1972/12/05/stocks.csv
#   inflating: stocks/1972/12/06/stocks.csv
#   inflating: stocks/1972/12/07/stocks.csv
#   inflating: stocks/1972/12/08/stocks.csv
#   inflating: stocks/1972/12/11/stocks.csv
#   inflating: stocks/1972/12/12/stocks.csv
#   inflating: stocks/1972/12/13/stocks.csv
#   inflating: stocks/1972/12/14/stocks.csv
#   inflating: stocks/1972/12/15/stocks.csv
#   inflating: stocks/1972/12/18/stocks.csv
#   inflating: stocks/1972/12/19/stocks.csv
#   inflating: stocks/1972/12/20/stocks.csv
#   inflating: stocks/1972/12/21/stocks.csv
#   inflating: stocks/1972/12/22/stocks.csv
#   inflating: stocks/1972/12/26/stocks.csv
#   inflating: stocks/1972/12/27/stocks.csv
#   inflating: stocks/1972/12/29/stocks.csv
#   inflating: stocks/1972/01/14/stocks.csv
#   inflating: stocks/1972/01/17/stocks.csv
#   inflating: stocks/1972/01/18/stocks.csv
#   inflating: stocks/1972/01/19/stocks.csv
#   inflating: stocks/1972/01/20/stocks.csv
#   inflating: stocks/1972/01/21/stocks.csv
#   inflating: stocks/1972/01/24/stocks.csv
#   inflating: stocks/1972/01/25/stocks.csv
#   inflating: stocks/1972/01/26/stocks.csv
#   inflating: stocks/1972/01/27/stocks.csv
#   inflating: stocks/1972/01/28/stocks.csv
#   inflating: stocks/1972/01/31/stocks.csv
#   inflating: stocks/1972/01/03/stocks.csv
#   inflating: stocks/1972/01/04/stocks.csv
#   inflating: stocks/1972/01/05/stocks.csv
#   inflating: stocks/1972/01/06/stocks.csv
#   inflating: stocks/1972/01/07/stocks.csv
#   inflating: stocks/1972/01/10/stocks.csv
#   inflating: stocks/1972/01/11/stocks.csv
#   inflating: stocks/1972/01/12/stocks.csv
#   inflating: stocks/1972/01/13/stocks.csv
#   inflating: stocks/1973/02/01/stocks.csv
#   inflating: stocks/1973/02/02/stocks.csv
#   inflating: stocks/1973/02/05/stocks.csv
#   inflating: stocks/1973/02/06/stocks.csv
#   inflating: stocks/1973/02/07/stocks.csv
#   inflating: stocks/1973/02/08/stocks.csv
#   inflating: stocks/1973/02/09/stocks.csv
#   inflating: stocks/1973/02/12/stocks.csv
#   inflating: stocks/1973/02/13/stocks.csv
#   inflating: stocks/1973/02/14/stocks.csv
#   inflating: stocks/1973/02/15/stocks.csv
#   inflating: stocks/1973/02/16/stocks.csv
#   inflating: stocks/1973/02/20/stocks.csv
#   inflating: stocks/1973/02/21/stocks.csv
#   inflating: stocks/1973/02/22/stocks.csv
#   inflating: stocks/1973/02/23/stocks.csv
#   inflating: stocks/1973/02/26/stocks.csv
#   inflating: stocks/1973/02/27/stocks.csv
#   inflating: stocks/1973/02/28/stocks.csv
#   inflating: stocks/1973/03/01/stocks.csv
#   inflating: stocks/1973/03/02/stocks.csv
#   inflating: stocks/1973/03/05/stocks.csv
#   inflating: stocks/1973/03/06/stocks.csv
#   inflating: stocks/1973/03/07/stocks.csv
#   inflating: stocks/1973/03/08/stocks.csv
#   inflating: stocks/1973/03/09/stocks.csv
#   inflating: stocks/1973/03/12/stocks.csv
#   inflating: stocks/1973/03/13/stocks.csv
#   inflating: stocks/1973/03/14/stocks.csv
#   inflating: stocks/1973/03/15/stocks.csv
#   inflating: stocks/1973/03/16/stocks.csv
#   inflating: stocks/1973/03/19/stocks.csv
#   inflating: stocks/1973/03/20/stocks.csv
#   inflating: stocks/1973/03/21/stocks.csv
#   inflating: stocks/1973/03/22/stocks.csv
#   inflating: stocks/1973/03/23/stocks.csv
#   inflating: stocks/1973/03/26/stocks.csv
#   inflating: stocks/1973/03/27/stocks.csv
#   inflating: stocks/1973/03/28/stocks.csv
#   inflating: stocks/1973/03/29/stocks.csv
#   inflating: stocks/1973/03/30/stocks.csv
#   inflating: stocks/1973/04/02/stocks.csv
#   inflating: stocks/1973/04/03/stocks.csv
#   inflating: stocks/1973/04/04/stocks.csv
#   inflating: stocks/1973/04/05/stocks.csv
#   inflating: stocks/1973/04/06/stocks.csv
#   inflating: stocks/1973/04/09/stocks.csv
#   inflating: stocks/1973/04/10/stocks.csv
#   inflating: stocks/1973/04/11/stocks.csv
#   inflating: stocks/1973/04/12/stocks.csv
#   inflating: stocks/1973/04/13/stocks.csv
#   inflating: stocks/1973/04/16/stocks.csv
#   inflating: stocks/1973/04/17/stocks.csv
#   inflating: stocks/1973/04/18/stocks.csv
#   inflating: stocks/1973/04/19/stocks.csv
#   inflating: stocks/1973/04/23/stocks.csv
#   inflating: stocks/1973/04/24/stocks.csv
#   inflating: stocks/1973/04/25/stocks.csv
#   inflating: stocks/1973/04/26/stocks.csv
#   inflating: stocks/1973/04/27/stocks.csv
#   inflating: stocks/1973/04/30/stocks.csv
#   inflating: stocks/1973/05/01/stocks.csv
#   inflating: stocks/1973/05/02/stocks.csv
#   inflating: stocks/1973/05/03/stocks.csv
#   inflating: stocks/1973/05/04/stocks.csv
#   inflating: stocks/1973/05/07/stocks.csv
#   inflating: stocks/1973/05/08/stocks.csv
#   inflating: stocks/1973/05/09/stocks.csv
#   inflating: stocks/1973/05/10/stocks.csv
#   inflating: stocks/1973/05/11/stocks.csv
#   inflating: stocks/1973/05/14/stocks.csv
#   inflating: stocks/1973/05/15/stocks.csv
#   inflating: stocks/1973/05/16/stocks.csv
#   inflating: stocks/1973/05/17/stocks.csv
#   inflating: stocks/1973/05/18/stocks.csv
#   inflating: stocks/1973/05/21/stocks.csv
#   inflating: stocks/1973/05/22/stocks.csv
#   inflating: stocks/1973/05/23/stocks.csv
#   inflating: stocks/1973/05/24/stocks.csv
#   inflating: stocks/1973/05/25/stocks.csv
#   inflating: stocks/1973/05/29/stocks.csv
#   inflating: stocks/1973/05/30/stocks.csv
#   inflating: stocks/1973/05/31/stocks.csv
#   inflating: stocks/1973/06/01/stocks.csv
#   inflating: stocks/1973/06/04/stocks.csv
#   inflating: stocks/1973/06/05/stocks.csv
#   inflating: stocks/1973/06/06/stocks.csv
#   inflating: stocks/1973/06/07/stocks.csv
#   inflating: stocks/1973/06/08/stocks.csv
#   inflating: stocks/1973/06/11/stocks.csv
#   inflating: stocks/1973/06/12/stocks.csv
#   inflating: stocks/1973/06/13/stocks.csv
#   inflating: stocks/1973/06/14/stocks.csv
#   inflating: stocks/1973/06/15/stocks.csv
#   inflating: stocks/1973/06/18/stocks.csv
#   inflating: stocks/1973/06/19/stocks.csv
#   inflating: stocks/1973/06/20/stocks.csv
#   inflating: stocks/1973/06/21/stocks.csv
#   inflating: stocks/1973/06/22/stocks.csv
#   inflating: stocks/1973/06/25/stocks.csv
#   inflating: stocks/1973/06/26/stocks.csv
#   inflating: stocks/1973/06/27/stocks.csv
#   inflating: stocks/1973/06/28/stocks.csv
#   inflating: stocks/1973/06/29/stocks.csv
#   inflating: stocks/1973/07/02/stocks.csv
#   inflating: stocks/1973/07/03/stocks.csv
#   inflating: stocks/1973/07/05/stocks.csv
#   inflating: stocks/1973/07/06/stocks.csv
#   inflating: stocks/1973/07/09/stocks.csv
#   inflating: stocks/1973/07/10/stocks.csv
#   inflating: stocks/1973/07/11/stocks.csv
#   inflating: stocks/1973/07/12/stocks.csv
#   inflating: stocks/1973/07/13/stocks.csv
#   inflating: stocks/1973/07/16/stocks.csv
#   inflating: stocks/1973/07/17/stocks.csv
#   inflating: stocks/1973/07/18/stocks.csv
#   inflating: stocks/1973/07/19/stocks.csv
#   inflating: stocks/1973/07/20/stocks.csv
#   inflating: stocks/1973/07/23/stocks.csv
#   inflating: stocks/1973/07/24/stocks.csv
#   inflating: stocks/1973/07/25/stocks.csv
#   inflating: stocks/1973/07/26/stocks.csv
#   inflating: stocks/1973/07/27/stocks.csv
#   inflating: stocks/1973/07/30/stocks.csv
#   inflating: stocks/1973/07/31/stocks.csv
#   inflating: stocks/1973/08/01/stocks.csv
#   inflating: stocks/1973/08/02/stocks.csv
#   inflating: stocks/1973/08/03/stocks.csv
#   inflating: stocks/1973/08/06/stocks.csv
#   inflating: stocks/1973/08/07/stocks.csv
#   inflating: stocks/1973/08/08/stocks.csv
#   inflating: stocks/1973/08/09/stocks.csv
#   inflating: stocks/1973/08/10/stocks.csv
#   inflating: stocks/1973/08/13/stocks.csv
#   inflating: stocks/1973/08/14/stocks.csv
#   inflating: stocks/1973/08/15/stocks.csv
#   inflating: stocks/1973/08/16/stocks.csv
#   inflating: stocks/1973/08/17/stocks.csv
#   inflating: stocks/1973/08/20/stocks.csv
#   inflating: stocks/1973/08/21/stocks.csv
#   inflating: stocks/1973/08/22/stocks.csv
#   inflating: stocks/1973/08/23/stocks.csv
#   inflating: stocks/1973/08/24/stocks.csv
#   inflating: stocks/1973/08/27/stocks.csv
#   inflating: stocks/1973/08/28/stocks.csv
#   inflating: stocks/1973/08/29/stocks.csv
#   inflating: stocks/1973/08/30/stocks.csv
#   inflating: stocks/1973/08/31/stocks.csv
#   inflating: stocks/1973/09/04/stocks.csv
#   inflating: stocks/1973/09/05/stocks.csv
#   inflating: stocks/1973/09/06/stocks.csv
#   inflating: stocks/1973/09/07/stocks.csv
#   inflating: stocks/1973/09/10/stocks.csv
#   inflating: stocks/1973/09/11/stocks.csv
#   inflating: stocks/1973/09/12/stocks.csv
#   inflating: stocks/1973/09/13/stocks.csv
#   inflating: stocks/1973/09/14/stocks.csv
#   inflating: stocks/1973/09/17/stocks.csv
#   inflating: stocks/1973/09/18/stocks.csv
#   inflating: stocks/1973/09/19/stocks.csv
#   inflating: stocks/1973/09/20/stocks.csv
#   inflating: stocks/1973/09/21/stocks.csv
#   inflating: stocks/1973/09/24/stocks.csv
#   inflating: stocks/1973/09/25/stocks.csv
#   inflating: stocks/1973/09/26/stocks.csv
#   inflating: stocks/1973/09/27/stocks.csv
#   inflating: stocks/1973/09/28/stocks.csv
#   inflating: stocks/1973/10/01/stocks.csv
#   inflating: stocks/1973/10/02/stocks.csv
#   inflating: stocks/1973/10/03/stocks.csv
#   inflating: stocks/1973/10/04/stocks.csv
#   inflating: stocks/1973/10/05/stocks.csv
#   inflating: stocks/1973/10/08/stocks.csv
#   inflating: stocks/1973/10/09/stocks.csv
#   inflating: stocks/1973/10/10/stocks.csv
#   inflating: stocks/1973/10/11/stocks.csv
#   inflating: stocks/1973/10/12/stocks.csv
#   inflating: stocks/1973/10/15/stocks.csv
#   inflating: stocks/1973/10/16/stocks.csv
#   inflating: stocks/1973/10/17/stocks.csv
#   inflating: stocks/1973/10/18/stocks.csv
#   inflating: stocks/1973/10/19/stocks.csv
#   inflating: stocks/1973/10/22/stocks.csv
#   inflating: stocks/1973/10/23/stocks.csv
#   inflating: stocks/1973/10/24/stocks.csv
#   inflating: stocks/1973/10/25/stocks.csv
#   inflating: stocks/1973/10/26/stocks.csv
#   inflating: stocks/1973/10/29/stocks.csv
#   inflating: stocks/1973/10/30/stocks.csv
#   inflating: stocks/1973/10/31/stocks.csv
#   inflating: stocks/1973/11/01/stocks.csv
#   inflating: stocks/1973/11/02/stocks.csv
#   inflating: stocks/1973/11/05/stocks.csv
#   inflating: stocks/1973/11/06/stocks.csv
#   inflating: stocks/1973/11/07/stocks.csv
#   inflating: stocks/1973/11/08/stocks.csv
#   inflating: stocks/1973/11/09/stocks.csv
#   inflating: stocks/1973/11/12/stocks.csv
#   inflating: stocks/1973/11/13/stocks.csv
#   inflating: stocks/1973/11/14/stocks.csv
#   inflating: stocks/1973/11/15/stocks.csv
#   inflating: stocks/1973/11/16/stocks.csv
#   inflating: stocks/1973/11/19/stocks.csv
#   inflating: stocks/1973/11/20/stocks.csv
#   inflating: stocks/1973/11/21/stocks.csv
#   inflating: stocks/1973/11/23/stocks.csv
#   inflating: stocks/1973/11/26/stocks.csv
#   inflating: stocks/1973/11/27/stocks.csv
#   inflating: stocks/1973/11/28/stocks.csv
#   inflating: stocks/1973/11/29/stocks.csv
#   inflating: stocks/1973/11/30/stocks.csv
#   inflating: stocks/1973/12/03/stocks.csv
#   inflating: stocks/1973/12/04/stocks.csv
#   inflating: stocks/1973/12/05/stocks.csv
#   inflating: stocks/1973/12/06/stocks.csv
#   inflating: stocks/1973/12/07/stocks.csv
#   inflating: stocks/1973/12/10/stocks.csv
#   inflating: stocks/1973/12/11/stocks.csv
#   inflating: stocks/1973/12/12/stocks.csv
#   inflating: stocks/1973/12/13/stocks.csv
#   inflating: stocks/1973/12/14/stocks.csv
#   inflating: stocks/1973/12/17/stocks.csv
#   inflating: stocks/1973/12/18/stocks.csv
#   inflating: stocks/1973/12/19/stocks.csv
#   inflating: stocks/1973/12/20/stocks.csv
#   inflating: stocks/1973/12/21/stocks.csv
#   inflating: stocks/1973/12/24/stocks.csv
#   inflating: stocks/1973/12/26/stocks.csv
#   inflating: stocks/1973/12/27/stocks.csv
#   inflating: stocks/1973/12/28/stocks.csv
#   inflating: stocks/1973/12/31/stocks.csv
#   inflating: stocks/1973/01/12/stocks.csv
#   inflating: stocks/1973/01/15/stocks.csv
#   inflating: stocks/1973/01/16/stocks.csv
#   inflating: stocks/1973/01/17/stocks.csv
#   inflating: stocks/1973/01/18/stocks.csv
#   inflating: stocks/1973/01/19/stocks.csv
#   inflating: stocks/1973/01/22/stocks.csv
#   inflating: stocks/1973/01/23/stocks.csv
#   inflating: stocks/1973/01/24/stocks.csv
#   inflating: stocks/1973/01/26/stocks.csv
#   inflating: stocks/1973/01/29/stocks.csv
#   inflating: stocks/1973/01/30/stocks.csv
#   inflating: stocks/1973/01/31/stocks.csv
#   inflating: stocks/1973/01/02/stocks.csv
#   inflating: stocks/1973/01/03/stocks.csv
#   inflating: stocks/1973/01/04/stocks.csv
#   inflating: stocks/1973/01/05/stocks.csv
#   inflating: stocks/1973/01/08/stocks.csv
#   inflating: stocks/1973/01/09/stocks.csv
#   inflating: stocks/1973/01/10/stocks.csv
#   inflating: stocks/1973/01/11/stocks.csv
#   inflating: stocks/1974/03/01/stocks.csv
#   inflating: stocks/1974/03/04/stocks.csv
#   inflating: stocks/1974/03/05/stocks.csv
#   inflating: stocks/1974/03/06/stocks.csv
#   inflating: stocks/1974/03/07/stocks.csv
#   inflating: stocks/1974/03/08/stocks.csv
#   inflating: stocks/1974/03/11/stocks.csv
#   inflating: stocks/1974/03/12/stocks.csv
#   inflating: stocks/1974/03/13/stocks.csv
#   inflating: stocks/1974/03/14/stocks.csv
#   inflating: stocks/1974/03/15/stocks.csv
#   inflating: stocks/1974/03/18/stocks.csv
#   inflating: stocks/1974/03/19/stocks.csv
#   inflating: stocks/1974/03/20/stocks.csv
#   inflating: stocks/1974/03/21/stocks.csv
#   inflating: stocks/1974/03/22/stocks.csv
#   inflating: stocks/1974/03/25/stocks.csv
#   inflating: stocks/1974/03/26/stocks.csv
#   inflating: stocks/1974/03/27/stocks.csv
#   inflating: stocks/1974/03/28/stocks.csv
#   inflating: stocks/1974/03/29/stocks.csv
#   inflating: stocks/1974/04/01/stocks.csv
#   inflating: stocks/1974/04/02/stocks.csv
#   inflating: stocks/1974/04/03/stocks.csv
#   inflating: stocks/1974/04/04/stocks.csv
#   inflating: stocks/1974/04/05/stocks.csv
#   inflating: stocks/1974/04/08/stocks.csv
#   inflating: stocks/1974/04/09/stocks.csv
#   inflating: stocks/1974/04/10/stocks.csv
#   inflating: stocks/1974/04/11/stocks.csv
#   inflating: stocks/1974/04/15/stocks.csv
#   inflating: stocks/1974/04/16/stocks.csv
#   inflating: stocks/1974/04/17/stocks.csv
#   inflating: stocks/1974/04/18/stocks.csv
#   inflating: stocks/1974/04/19/stocks.csv
#   inflating: stocks/1974/04/22/stocks.csv
#   inflating: stocks/1974/04/23/stocks.csv
#   inflating: stocks/1974/04/24/stocks.csv
#   inflating: stocks/1974/04/25/stocks.csv
#   inflating: stocks/1974/04/26/stocks.csv
#   inflating: stocks/1974/04/29/stocks.csv
#   inflating: stocks/1974/04/30/stocks.csv
#   inflating: stocks/1974/05/01/stocks.csv
#   inflating: stocks/1974/05/02/stocks.csv
#   inflating: stocks/1974/05/03/stocks.csv
#   inflating: stocks/1974/05/06/stocks.csv
#   inflating: stocks/1974/05/07/stocks.csv
#   inflating: stocks/1974/05/08/stocks.csv
#   inflating: stocks/1974/05/09/stocks.csv
#   inflating: stocks/1974/05/10/stocks.csv
#   inflating: stocks/1974/05/13/stocks.csv
#   inflating: stocks/1974/05/14/stocks.csv
#   inflating: stocks/1974/05/15/stocks.csv
#   inflating: stocks/1974/05/16/stocks.csv
#   inflating: stocks/1974/05/17/stocks.csv
#   inflating: stocks/1974/05/20/stocks.csv
#   inflating: stocks/1974/05/21/stocks.csv
#   inflating: stocks/1974/05/22/stocks.csv
#   inflating: stocks/1974/05/23/stocks.csv
#   inflating: stocks/1974/05/24/stocks.csv
#   inflating: stocks/1974/05/28/stocks.csv
#   inflating: stocks/1974/05/29/stocks.csv
#   inflating: stocks/1974/05/30/stocks.csv
#   inflating: stocks/1974/05/31/stocks.csv
#   inflating: stocks/1974/06/03/stocks.csv
#   inflating: stocks/1974/06/04/stocks.csv
#   inflating: stocks/1974/06/05/stocks.csv
#   inflating: stocks/1974/06/06/stocks.csv
#   inflating: stocks/1974/06/07/stocks.csv
#   inflating: stocks/1974/06/10/stocks.csv
#   inflating: stocks/1974/06/11/stocks.csv
#   inflating: stocks/1974/06/12/stocks.csv
#   inflating: stocks/1974/06/13/stocks.csv
#   inflating: stocks/1974/06/14/stocks.csv
#   inflating: stocks/1974/06/17/stocks.csv
#   inflating: stocks/1974/06/18/stocks.csv
#   inflating: stocks/1974/06/19/stocks.csv
#   inflating: stocks/1974/06/20/stocks.csv
#   inflating: stocks/1974/06/21/stocks.csv
#   inflating: stocks/1974/06/24/stocks.csv
#   inflating: stocks/1974/06/25/stocks.csv
#   inflating: stocks/1974/06/26/stocks.csv
#   inflating: stocks/1974/06/27/stocks.csv
#   inflating: stocks/1974/06/28/stocks.csv
#   inflating: stocks/1974/07/01/stocks.csv
#   inflating: stocks/1974/07/02/stocks.csv
#   inflating: stocks/1974/07/03/stocks.csv
#   inflating: stocks/1974/07/05/stocks.csv
#   inflating: stocks/1974/07/08/stocks.csv
#   inflating: stocks/1974/07/09/stocks.csv
#   inflating: stocks/1974/07/10/stocks.csv
#   inflating: stocks/1974/07/11/stocks.csv
#   inflating: stocks/1974/07/12/stocks.csv
#   inflating: stocks/1974/07/15/stocks.csv
#   inflating: stocks/1974/07/16/stocks.csv
#   inflating: stocks/1974/07/17/stocks.csv
#   inflating: stocks/1974/07/18/stocks.csv
#   inflating: stocks/1974/07/19/stocks.csv
#   inflating: stocks/1974/07/22/stocks.csv
#   inflating: stocks/1974/07/23/stocks.csv
#   inflating: stocks/1974/07/24/stocks.csv
#   inflating: stocks/1974/07/25/stocks.csv
#   inflating: stocks/1974/07/26/stocks.csv
#   inflating: stocks/1974/07/29/stocks.csv
#   inflating: stocks/1974/07/30/stocks.csv
#   inflating: stocks/1974/07/31/stocks.csv
#   inflating: stocks/1974/08/01/stocks.csv
#   inflating: stocks/1974/08/02/stocks.csv
#   inflating: stocks/1974/08/05/stocks.csv
#   inflating: stocks/1974/08/06/stocks.csv
#   inflating: stocks/1974/08/07/stocks.csv
#   inflating: stocks/1974/08/08/stocks.csv
#   inflating: stocks/1974/08/09/stocks.csv
#   inflating: stocks/1974/08/12/stocks.csv
#   inflating: stocks/1974/08/13/stocks.csv
#   inflating: stocks/1974/08/14/stocks.csv
#   inflating: stocks/1974/08/15/stocks.csv
#   inflating: stocks/1974/08/16/stocks.csv
#   inflating: stocks/1974/08/19/stocks.csv
#   inflating: stocks/1974/08/20/stocks.csv
#   inflating: stocks/1974/08/21/stocks.csv
#   inflating: stocks/1974/08/22/stocks.csv
#   inflating: stocks/1974/08/23/stocks.csv
#   inflating: stocks/1974/08/26/stocks.csv
#   inflating: stocks/1974/08/27/stocks.csv
#   inflating: stocks/1974/08/28/stocks.csv
#   inflating: stocks/1974/08/29/stocks.csv
#   inflating: stocks/1974/08/30/stocks.csv
#   inflating: stocks/1974/09/03/stocks.csv
#   inflating: stocks/1974/09/04/stocks.csv
#   inflating: stocks/1974/09/05/stocks.csv
#   inflating: stocks/1974/09/06/stocks.csv
#   inflating: stocks/1974/09/09/stocks.csv
#   inflating: stocks/1974/09/10/stocks.csv
#   inflating: stocks/1974/09/11/stocks.csv
#   inflating: stocks/1974/09/12/stocks.csv
#   inflating: stocks/1974/09/13/stocks.csv
#   inflating: stocks/1974/09/16/stocks.csv
#   inflating: stocks/1974/09/17/stocks.csv
#   inflating: stocks/1974/09/18/stocks.csv
#   inflating: stocks/1974/09/19/stocks.csv
#   inflating: stocks/1974/09/20/stocks.csv
#   inflating: stocks/1974/09/23/stocks.csv
#   inflating: stocks/1974/09/24/stocks.csv
#   inflating: stocks/1974/09/25/stocks.csv
#   inflating: stocks/1974/09/26/stocks.csv
#   inflating: stocks/1974/09/27/stocks.csv
#   inflating: stocks/1974/09/30/stocks.csv
#   inflating: stocks/1974/10/01/stocks.csv
#   inflating: stocks/1974/10/02/stocks.csv
#   inflating: stocks/1974/10/03/stocks.csv
#   inflating: stocks/1974/10/04/stocks.csv
#   inflating: stocks/1974/10/07/stocks.csv
#   inflating: stocks/1974/10/08/stocks.csv
#   inflating: stocks/1974/10/09/stocks.csv
#   inflating: stocks/1974/10/10/stocks.csv
#   inflating: stocks/1974/10/11/stocks.csv
#   inflating: stocks/1974/10/14/stocks.csv
#   inflating: stocks/1974/10/15/stocks.csv
#   inflating: stocks/1974/10/16/stocks.csv
#   inflating: stocks/1974/10/17/stocks.csv
#   inflating: stocks/1974/10/18/stocks.csv
#   inflating: stocks/1974/10/21/stocks.csv
#   inflating: stocks/1974/10/22/stocks.csv
#   inflating: stocks/1974/10/23/stocks.csv
#   inflating: stocks/1974/10/24/stocks.csv
#   inflating: stocks/1974/10/25/stocks.csv
#   inflating: stocks/1974/10/28/stocks.csv
#   inflating: stocks/1974/10/29/stocks.csv
#   inflating: stocks/1974/10/30/stocks.csv
#   inflating: stocks/1974/10/31/stocks.csv
#   inflating: stocks/1974/11/01/stocks.csv
#   inflating: stocks/1974/11/04/stocks.csv
#   inflating: stocks/1974/11/05/stocks.csv
#   inflating: stocks/1974/11/06/stocks.csv
#   inflating: stocks/1974/11/07/stocks.csv
#   inflating: stocks/1974/11/08/stocks.csv
#   inflating: stocks/1974/11/11/stocks.csv
#   inflating: stocks/1974/11/12/stocks.csv
#   inflating: stocks/1974/11/13/stocks.csv
#   inflating: stocks/1974/11/14/stocks.csv
#   inflating: stocks/1974/11/15/stocks.csv
#   inflating: stocks/1974/11/18/stocks.csv
#   inflating: stocks/1974/11/19/stocks.csv
#   inflating: stocks/1974/11/20/stocks.csv
#   inflating: stocks/1974/11/21/stocks.csv
#   inflating: stocks/1974/11/22/stocks.csv
#   inflating: stocks/1974/11/25/stocks.csv
#   inflating: stocks/1974/11/26/stocks.csv
#   inflating: stocks/1974/11/27/stocks.csv
#   inflating: stocks/1974/11/29/stocks.csv
#   inflating: stocks/1974/12/02/stocks.csv
#   inflating: stocks/1974/12/03/stocks.csv
#   inflating: stocks/1974/12/04/stocks.csv
#   inflating: stocks/1974/12/05/stocks.csv
#   inflating: stocks/1974/12/06/stocks.csv
#   inflating: stocks/1974/12/09/stocks.csv
#   inflating: stocks/1974/12/10/stocks.csv
#   inflating: stocks/1974/12/11/stocks.csv
#   inflating: stocks/1974/12/12/stocks.csv
#   inflating: stocks/1974/12/13/stocks.csv
#   inflating: stocks/1974/12/16/stocks.csv
#   inflating: stocks/1974/12/17/stocks.csv
#   inflating: stocks/1974/12/18/stocks.csv
#   inflating: stocks/1974/12/19/stocks.csv
#   inflating: stocks/1974/12/20/stocks.csv
#   inflating: stocks/1974/12/23/stocks.csv
#   inflating: stocks/1974/12/24/stocks.csv
#   inflating: stocks/1974/12/26/stocks.csv
#   inflating: stocks/1974/12/27/stocks.csv
#   inflating: stocks/1974/12/30/stocks.csv
#   inflating: stocks/1974/12/31/stocks.csv
#   inflating: stocks/1974/01/14/stocks.csv
#   inflating: stocks/1974/01/15/stocks.csv
#   inflating: stocks/1974/01/16/stocks.csv
#   inflating: stocks/1974/01/17/stocks.csv
#   inflating: stocks/1974/01/18/stocks.csv
#   inflating: stocks/1974/01/21/stocks.csv
#   inflating: stocks/1974/01/22/stocks.csv
#   inflating: stocks/1974/01/23/stocks.csv
#   inflating: stocks/1974/01/24/stocks.csv
#   inflating: stocks/1974/01/25/stocks.csv
#   inflating: stocks/1974/01/28/stocks.csv
#   inflating: stocks/1974/01/29/stocks.csv
#   inflating: stocks/1974/01/30/stocks.csv
#   inflating: stocks/1974/01/31/stocks.csv
#   inflating: stocks/1974/01/02/stocks.csv
#   inflating: stocks/1974/01/03/stocks.csv
#   inflating: stocks/1974/01/04/stocks.csv
#   inflating: stocks/1974/01/07/stocks.csv
#   inflating: stocks/1974/01/08/stocks.csv
#   inflating: stocks/1974/01/09/stocks.csv
#   inflating: stocks/1974/01/10/stocks.csv
#   inflating: stocks/1974/01/11/stocks.csv
#   inflating: stocks/1974/02/01/stocks.csv
#   inflating: stocks/1974/02/04/stocks.csv
#   inflating: stocks/1974/02/05/stocks.csv
#   inflating: stocks/1974/02/06/stocks.csv
#   inflating: stocks/1974/02/07/stocks.csv
#   inflating: stocks/1974/02/08/stocks.csv
#   inflating: stocks/1974/02/11/stocks.csv
#   inflating: stocks/1974/02/12/stocks.csv
#   inflating: stocks/1974/02/13/stocks.csv
#   inflating: stocks/1974/02/14/stocks.csv
#   inflating: stocks/1974/02/15/stocks.csv
#   inflating: stocks/1974/02/19/stocks.csv
#   inflating: stocks/1974/02/20/stocks.csv
#   inflating: stocks/1974/02/21/stocks.csv
#   inflating: stocks/1974/02/22/stocks.csv
#   inflating: stocks/1974/02/25/stocks.csv
#   inflating: stocks/1974/02/26/stocks.csv
#   inflating: stocks/1974/02/27/stocks.csv
#   inflating: stocks/1974/02/28/stocks.csv
#   inflating: stocks/1975/04/01/stocks.csv
#   inflating: stocks/1975/04/02/stocks.csv
#   inflating: stocks/1975/04/03/stocks.csv
#   inflating: stocks/1975/04/04/stocks.csv
#   inflating: stocks/1975/04/07/stocks.csv
#   inflating: stocks/1975/04/08/stocks.csv
#   inflating: stocks/1975/04/09/stocks.csv
#   inflating: stocks/1975/04/10/stocks.csv
#   inflating: stocks/1975/04/11/stocks.csv
#   inflating: stocks/1975/04/14/stocks.csv
#   inflating: stocks/1975/04/15/stocks.csv
#   inflating: stocks/1975/04/16/stocks.csv
#   inflating: stocks/1975/04/17/stocks.csv
#   inflating: stocks/1975/04/18/stocks.csv
#   inflating: stocks/1975/04/21/stocks.csv
#   inflating: stocks/1975/04/22/stocks.csv
#   inflating: stocks/1975/04/23/stocks.csv
#   inflating: stocks/1975/04/24/stocks.csv
#   inflating: stocks/1975/04/25/stocks.csv
#   inflating: stocks/1975/04/28/stocks.csv
#   inflating: stocks/1975/04/29/stocks.csv
#   inflating: stocks/1975/04/30/stocks.csv
#   inflating: stocks/1975/05/01/stocks.csv
#   inflating: stocks/1975/05/02/stocks.csv
#   inflating: stocks/1975/05/05/stocks.csv
#   inflating: stocks/1975/05/06/stocks.csv
#   inflating: stocks/1975/05/07/stocks.csv
#   inflating: stocks/1975/05/08/stocks.csv
#   inflating: stocks/1975/05/09/stocks.csv
#   inflating: stocks/1975/05/12/stocks.csv
#   inflating: stocks/1975/05/13/stocks.csv
#   inflating: stocks/1975/05/14/stocks.csv
#   inflating: stocks/1975/05/15/stocks.csv
#   inflating: stocks/1975/05/16/stocks.csv
#   inflating: stocks/1975/05/19/stocks.csv
#   inflating: stocks/1975/05/20/stocks.csv
#   inflating: stocks/1975/05/21/stocks.csv
#   inflating: stocks/1975/05/22/stocks.csv
#   inflating: stocks/1975/05/23/stocks.csv
#   inflating: stocks/1975/05/27/stocks.csv
#   inflating: stocks/1975/05/28/stocks.csv
#   inflating: stocks/1975/05/29/stocks.csv
#   inflating: stocks/1975/05/30/stocks.csv
#   inflating: stocks/1975/06/02/stocks.csv
#   inflating: stocks/1975/06/03/stocks.csv
#   inflating: stocks/1975/06/04/stocks.csv
#   inflating: stocks/1975/06/05/stocks.csv
#   inflating: stocks/1975/06/06/stocks.csv
#   inflating: stocks/1975/06/09/stocks.csv
#   inflating: stocks/1975/06/10/stocks.csv
#   inflating: stocks/1975/06/11/stocks.csv
#   inflating: stocks/1975/06/12/stocks.csv
#   inflating: stocks/1975/06/13/stocks.csv
#   inflating: stocks/1975/06/16/stocks.csv
#   inflating: stocks/1975/06/17/stocks.csv
#   inflating: stocks/1975/06/18/stocks.csv
#   inflating: stocks/1975/06/19/stocks.csv
#   inflating: stocks/1975/06/20/stocks.csv
#   inflating: stocks/1975/06/23/stocks.csv
#   inflating: stocks/1975/06/24/stocks.csv
#   inflating: stocks/1975/06/25/stocks.csv
#   inflating: stocks/1975/06/26/stocks.csv
#   inflating: stocks/1975/06/27/stocks.csv
#   inflating: stocks/1975/06/30/stocks.csv
#   inflating: stocks/1975/07/01/stocks.csv
#   inflating: stocks/1975/07/02/stocks.csv
#   inflating: stocks/1975/07/03/stocks.csv
#   inflating: stocks/1975/07/07/stocks.csv
#   inflating: stocks/1975/07/08/stocks.csv
#   inflating: stocks/1975/07/09/stocks.csv
#   inflating: stocks/1975/07/10/stocks.csv
#   inflating: stocks/1975/07/11/stocks.csv
#   inflating: stocks/1975/07/14/stocks.csv
#   inflating: stocks/1975/07/15/stocks.csv
#   inflating: stocks/1975/07/16/stocks.csv
#   inflating: stocks/1975/07/17/stocks.csv
#   inflating: stocks/1975/07/18/stocks.csv
#   inflating: stocks/1975/07/21/stocks.csv
#   inflating: stocks/1975/07/22/stocks.csv
#   inflating: stocks/1975/07/23/stocks.csv
#   inflating: stocks/1975/07/24/stocks.csv
#   inflating: stocks/1975/07/25/stocks.csv
#   inflating: stocks/1975/07/28/stocks.csv
#   inflating: stocks/1975/07/29/stocks.csv
#   inflating: stocks/1975/07/30/stocks.csv
#   inflating: stocks/1975/07/31/stocks.csv
#   inflating: stocks/1975/08/01/stocks.csv
#   inflating: stocks/1975/08/04/stocks.csv
#   inflating: stocks/1975/08/05/stocks.csv
#   inflating: stocks/1975/08/06/stocks.csv
#   inflating: stocks/1975/08/07/stocks.csv
#   inflating: stocks/1975/08/08/stocks.csv
#   inflating: stocks/1975/08/11/stocks.csv
#   inflating: stocks/1975/08/12/stocks.csv
#   inflating: stocks/1975/08/13/stocks.csv
#   inflating: stocks/1975/08/14/stocks.csv
#   inflating: stocks/1975/08/15/stocks.csv
#   inflating: stocks/1975/08/18/stocks.csv
#   inflating: stocks/1975/08/19/stocks.csv
#   inflating: stocks/1975/08/20/stocks.csv
#   inflating: stocks/1975/08/21/stocks.csv
#   inflating: stocks/1975/08/22/stocks.csv
#   inflating: stocks/1975/08/25/stocks.csv
#   inflating: stocks/1975/08/26/stocks.csv
#   inflating: stocks/1975/08/27/stocks.csv
#   inflating: stocks/1975/08/28/stocks.csv
#   inflating: stocks/1975/08/29/stocks.csv
#   inflating: stocks/1975/09/02/stocks.csv
#   inflating: stocks/1975/09/03/stocks.csv
#   inflating: stocks/1975/09/04/stocks.csv
#   inflating: stocks/1975/09/05/stocks.csv
#   inflating: stocks/1975/09/08/stocks.csv
#   inflating: stocks/1975/09/09/stocks.csv
#   inflating: stocks/1975/09/10/stocks.csv
#   inflating: stocks/1975/09/11/stocks.csv
#   inflating: stocks/1975/09/12/stocks.csv
#   inflating: stocks/1975/09/15/stocks.csv
#   inflating: stocks/1975/09/16/stocks.csv
#   inflating: stocks/1975/09/17/stocks.csv
#   inflating: stocks/1975/09/18/stocks.csv
#   inflating: stocks/1975/09/19/stocks.csv
#   inflating: stocks/1975/09/22/stocks.csv
#   inflating: stocks/1975/09/23/stocks.csv
#   inflating: stocks/1975/09/24/stocks.csv
#   inflating: stocks/1975/09/25/stocks.csv
#   inflating: stocks/1975/09/26/stocks.csv
#   inflating: stocks/1975/09/29/stocks.csv
#   inflating: stocks/1975/09/30/stocks.csv
#   inflating: stocks/1975/10/01/stocks.csv
#   inflating: stocks/1975/10/02/stocks.csv
#   inflating: stocks/1975/10/03/stocks.csv
#   inflating: stocks/1975/10/06/stocks.csv
#   inflating: stocks/1975/10/07/stocks.csv
#   inflating: stocks/1975/10/08/stocks.csv
#   inflating: stocks/1975/10/09/stocks.csv
#   inflating: stocks/1975/10/10/stocks.csv
#   inflating: stocks/1975/10/13/stocks.csv
#   inflating: stocks/1975/10/14/stocks.csv
#   inflating: stocks/1975/10/15/stocks.csv
#   inflating: stocks/1975/10/16/stocks.csv
#   inflating: stocks/1975/10/17/stocks.csv
#   inflating: stocks/1975/10/20/stocks.csv
#   inflating: stocks/1975/10/21/stocks.csv
#   inflating: stocks/1975/10/22/stocks.csv
#   inflating: stocks/1975/10/23/stocks.csv
#   inflating: stocks/1975/10/24/stocks.csv
#   inflating: stocks/1975/10/27/stocks.csv
#   inflating: stocks/1975/10/28/stocks.csv
#   inflating: stocks/1975/10/29/stocks.csv
#   inflating: stocks/1975/10/30/stocks.csv
#   inflating: stocks/1975/10/31/stocks.csv
#   inflating: stocks/1975/11/03/stocks.csv
#   inflating: stocks/1975/11/04/stocks.csv
#   inflating: stocks/1975/11/05/stocks.csv
#   inflating: stocks/1975/11/06/stocks.csv
#   inflating: stocks/1975/11/07/stocks.csv
#   inflating: stocks/1975/11/10/stocks.csv
#   inflating: stocks/1975/11/11/stocks.csv
#   inflating: stocks/1975/11/12/stocks.csv
#   inflating: stocks/1975/11/13/stocks.csv
#   inflating: stocks/1975/11/14/stocks.csv
#   inflating: stocks/1975/11/17/stocks.csv
#   inflating: stocks/1975/11/18/stocks.csv
#   inflating: stocks/1975/11/19/stocks.csv
#   inflating: stocks/1975/11/20/stocks.csv
#   inflating: stocks/1975/11/21/stocks.csv
#   inflating: stocks/1975/11/24/stocks.csv
#   inflating: stocks/1975/11/25/stocks.csv
#   inflating: stocks/1975/11/26/stocks.csv
#   inflating: stocks/1975/11/28/stocks.csv
#   inflating: stocks/1975/12/01/stocks.csv
#   inflating: stocks/1975/12/02/stocks.csv
#   inflating: stocks/1975/12/03/stocks.csv
#   inflating: stocks/1975/12/04/stocks.csv
#   inflating: stocks/1975/12/05/stocks.csv
#   inflating: stocks/1975/12/08/stocks.csv
#   inflating: stocks/1975/12/09/stocks.csv
#   inflating: stocks/1975/12/10/stocks.csv
#   inflating: stocks/1975/12/11/stocks.csv
#   inflating: stocks/1975/12/12/stocks.csv
#   inflating: stocks/1975/12/15/stocks.csv
#   inflating: stocks/1975/12/16/stocks.csv
#   inflating: stocks/1975/12/17/stocks.csv
#   inflating: stocks/1975/12/18/stocks.csv
#   inflating: stocks/1975/12/19/stocks.csv
#   inflating: stocks/1975/12/22/stocks.csv
#   inflating: stocks/1975/12/23/stocks.csv
#   inflating: stocks/1975/12/24/stocks.csv
#   inflating: stocks/1975/12/26/stocks.csv
#   inflating: stocks/1975/12/29/stocks.csv
#   inflating: stocks/1975/12/30/stocks.csv
#   inflating: stocks/1975/12/31/stocks.csv
#   inflating: stocks/1975/01/13/stocks.csv
#   inflating: stocks/1975/01/14/stocks.csv
#   inflating: stocks/1975/01/15/stocks.csv
#   inflating: stocks/1975/01/16/stocks.csv
#   inflating: stocks/1975/01/17/stocks.csv
#   inflating: stocks/1975/01/20/stocks.csv
#   inflating: stocks/1975/01/21/stocks.csv
#   inflating: stocks/1975/01/22/stocks.csv
#   inflating: stocks/1975/01/23/stocks.csv
#   inflating: stocks/1975/01/24/stocks.csv
#   inflating: stocks/1975/01/27/stocks.csv
#   inflating: stocks/1975/01/28/stocks.csv
# ...
#   inflating: stocks/1989/11/22/stocks.csv
#   inflating: stocks/1989/11/24/stocks.csv
#   inflating: stocks/1989/11/27/stocks.csv
#   inflating: stocks/1989/11/28/stocks.csv
#   inflating: stocks/1989/11/29/stocks.csv
#   inflating: stocks/1989/11/30/stocks.csv
#   inflating: stocks/1989/12/01/stocks.csv
#   inflating: stocks/1989/12/04/stocks.csv
#   inflating: stocks/1989/12/05/stocks.csv
#   inflating: stocks/1989/12/06/stocks.csv
#   inflating: stocks/1989/12/07/stocks.csv
#   inflating: stocks/1989/12/08/stocks.csv
#   inflating: stocks/1989/12/11/stocks.csv
#   inflating: stocks/1989/12/12/stocks.csv
#   inflating: stocks/1989/12/13/stocks.csv
#   inflating: stocks/1989/12/14/stocks.csv
#   inflating: stocks/1989/12/15/stocks.csv
#   inflating: stocks/1989/12/18/stocks.csv
#   inflating: stocks/1989/12/19/stocks.csv
#   inflating: stocks/1989/12/20/stocks.csv
#   inflating: stocks/1989/12/21/stocks.csv
#   inflating: stocks/1989/12/22/stocks.csv
#   inflating: stocks/1989/12/26/stocks.csv
#   inflating: stocks/1989/12/27/stocks.csv
#   inflating: stocks/1989/12/28/stocks.csv
#   inflating: stocks/1989/12/29/stocks.csv
#   inflating: stocks/1989/01/12/stocks.csv
#   inflating: stocks/1989/01/13/stocks.csv
#   inflating: stocks/1989/01/16/stocks.csv
#   inflating: stocks/1989/01/17/stocks.csv
#   inflating: stocks/1989/01/18/stocks.csv
#   inflating: stocks/1989/01/19/stocks.csv
#   inflating: stocks/1989/01/20/stocks.csv
#   inflating: stocks/1989/01/23/stocks.csv
#   inflating: stocks/1989/01/24/stocks.csv
#   inflating: stocks/1989/01/25/stocks.csv
#   inflating: stocks/1989/01/26/stocks.csv
#   inflating: stocks/1989/01/27/stocks.csv
#   inflating: stocks/1989/01/30/stocks.csv
#   inflating: stocks/1989/01/31/stocks.csv
#   inflating: stocks/1989/01/03/stocks.csv
#   inflating: stocks/1989/01/04/stocks.csv
#   inflating: stocks/1989/01/05/stocks.csv
#   inflating: stocks/1989/01/06/stocks.csv
#   inflating: stocks/1989/01/09/stocks.csv
#   inflating: stocks/1989/01/10/stocks.csv
#   inflating: stocks/1989/01/11/stocks.csv
#   inflating: stocks/2019/05/01/stocks.csv
#   inflating: stocks/2019/05/02/stocks.csv
#   inflating: stocks/2019/05/03/stocks.csv
#   inflating: stocks/2019/05/06/stocks.csv
#   inflating: stocks/2019/05/07/stocks.csv
#   inflating: stocks/2019/05/08/stocks.csv
#   inflating: stocks/2019/05/09/stocks.csv
#   inflating: stocks/2019/05/10/stocks.csv
#   inflating: stocks/2019/05/13/stocks.csv
#   inflating: stocks/2019/05/14/stocks.csv
#   inflating: stocks/2019/05/15/stocks.csv
#   inflating: stocks/2019/05/16/stocks.csv
#   inflating: stocks/2019/05/17/stocks.csv
#   inflating: stocks/2019/05/20/stocks.csv
#   inflating: stocks/2019/05/21/stocks.csv
#   inflating: stocks/2019/05/22/stocks.csv
#   inflating: stocks/2019/05/23/stocks.csv
#   inflating: stocks/2019/05/24/stocks.csv
#   inflating: stocks/2019/05/28/stocks.csv
#   inflating: stocks/2019/05/29/stocks.csv
#   inflating: stocks/2019/05/30/stocks.csv
#   inflating: stocks/2019/05/31/stocks.csv
#   inflating: stocks/2019/06/03/stocks.csv
#   inflating: stocks/2019/06/04/stocks.csv
#   inflating: stocks/2019/06/05/stocks.csv
#   inflating: stocks/2019/06/06/stocks.csv
#   inflating: stocks/2019/06/07/stocks.csv
#   inflating: stocks/2019/06/10/stocks.csv
#   inflating: stocks/2019/06/11/stocks.csv
#   inflating: stocks/2019/06/12/stocks.csv
#   inflating: stocks/2019/06/13/stocks.csv
#   inflating: stocks/2019/06/14/stocks.csv
#   inflating: stocks/2019/06/17/stocks.csv
#   inflating: stocks/2019/06/18/stocks.csv
#   inflating: stocks/2019/06/19/stocks.csv
#   inflating: stocks/2019/06/20/stocks.csv
#   inflating: stocks/2019/06/21/stocks.csv
#   inflating: stocks/2019/06/24/stocks.csv
#   inflating: stocks/2019/06/25/stocks.csv
#   inflating: stocks/2019/06/26/stocks.csv
#   inflating: stocks/2019/06/27/stocks.csv
#   inflating: stocks/2019/06/28/stocks.csv
#   inflating: stocks/2019/07/01/stocks.csv
#   inflating: stocks/2019/07/02/stocks.csv
#   inflating: stocks/2019/07/03/stocks.csv
#   inflating: stocks/2019/07/05/stocks.csv
#   inflating: stocks/2019/07/08/stocks.csv
#   inflating: stocks/2019/07/09/stocks.csv
#   inflating: stocks/2019/07/10/stocks.csv
#   inflating: stocks/2019/07/11/stocks.csv
#   inflating: stocks/2019/07/12/stocks.csv
#   inflating: stocks/2019/07/15/stocks.csv
#   inflating: stocks/2019/07/16/stocks.csv
#   inflating: stocks/2019/07/17/stocks.csv
#   inflating: stocks/2019/07/18/stocks.csv
#   inflating: stocks/2019/07/19/stocks.csv
#   inflating: stocks/2019/07/22/stocks.csv
#   inflating: stocks/2019/07/23/stocks.csv
#   inflating: stocks/2019/07/24/stocks.csv
#   inflating: stocks/2019/07/25/stocks.csv
#   inflating: stocks/2019/07/26/stocks.csv
#   inflating: stocks/2019/07/29/stocks.csv
#   inflating: stocks/2019/07/30/stocks.csv
#   inflating: stocks/2019/07/31/stocks.csv
#   inflating: stocks/2019/08/01/stocks.csv
#   inflating: stocks/2019/08/02/stocks.csv
#   inflating: stocks/2019/08/05/stocks.csv
#   inflating: stocks/2019/08/06/stocks.csv
#   inflating: stocks/2019/08/07/stocks.csv
#   inflating: stocks/2019/08/08/stocks.csv
#   inflating: stocks/2019/08/09/stocks.csv
#   inflating: stocks/2019/08/12/stocks.csv
#   inflating: stocks/2019/08/13/stocks.csv
#   inflating: stocks/2019/08/14/stocks.csv
#   inflating: stocks/2019/08/15/stocks.csv
#   inflating: stocks/2019/08/16/stocks.csv
#   inflating: stocks/2019/08/19/stocks.csv
#   inflating: stocks/2019/08/20/stocks.csv
#   inflating: stocks/2019/08/21/stocks.csv
#   inflating: stocks/2019/08/22/stocks.csv
#   inflating: stocks/2019/08/23/stocks.csv
#   inflating: stocks/2019/08/26/stocks.csv
#   inflating: stocks/2019/08/27/stocks.csv
#   inflating: stocks/2019/08/28/stocks.csv
#   inflating: stocks/2019/08/29/stocks.csv
#   inflating: stocks/2019/08/30/stocks.csv
#   inflating: stocks/2019/09/03/stocks.csv
#   inflating: stocks/2019/09/04/stocks.csv
#   inflating: stocks/2019/09/05/stocks.csv
#   inflating: stocks/2019/09/06/stocks.csv
#   inflating: stocks/2019/09/09/stocks.csv
#   inflating: stocks/2019/09/10/stocks.csv
#   inflating: stocks/2019/09/11/stocks.csv
#   inflating: stocks/2019/09/12/stocks.csv
#   inflating: stocks/2019/09/13/stocks.csv
#   inflating: stocks/2019/09/16/stocks.csv
#   inflating: stocks/2019/09/17/stocks.csv
#   inflating: stocks/2019/09/18/stocks.csv
#   inflating: stocks/2019/09/19/stocks.csv
#   inflating: stocks/2019/09/20/stocks.csv
#   inflating: stocks/2019/09/23/stocks.csv
#   inflating: stocks/2019/09/24/stocks.csv
#   inflating: stocks/2019/09/25/stocks.csv
#   inflating: stocks/2019/09/26/stocks.csv
#   inflating: stocks/2019/09/27/stocks.csv
#   inflating: stocks/2019/09/30/stocks.csv
#   inflating: stocks/2019/10/01/stocks.csv
#   inflating: stocks/2019/10/02/stocks.csv
#   inflating: stocks/2019/10/03/stocks.csv
#   inflating: stocks/2019/10/04/stocks.csv
#   inflating: stocks/2019/10/07/stocks.csv
#   inflating: stocks/2019/10/08/stocks.csv
#   inflating: stocks/2019/10/09/stocks.csv
#   inflating: stocks/2019/10/10/stocks.csv
#   inflating: stocks/2019/10/11/stocks.csv
#   inflating: stocks/2019/10/14/stocks.csv
#   inflating: stocks/2019/10/15/stocks.csv
#   inflating: stocks/2019/10/16/stocks.csv
#   inflating: stocks/2019/10/17/stocks.csv
#   inflating: stocks/2019/10/18/stocks.csv
#   inflating: stocks/2019/10/21/stocks.csv
#   inflating: stocks/2019/10/22/stocks.csv
#   inflating: stocks/2019/10/23/stocks.csv
#   inflating: stocks/2019/10/24/stocks.csv
#   inflating: stocks/2019/10/25/stocks.csv
#   inflating: stocks/2019/10/28/stocks.csv
#   inflating: stocks/2019/10/29/stocks.csv
#   inflating: stocks/2019/10/30/stocks.csv
#   inflating: stocks/2019/10/31/stocks.csv
#   inflating: stocks/2019/11/01/stocks.csv
#   inflating: stocks/2019/11/04/stocks.csv
#   inflating: stocks/2019/11/05/stocks.csv
#   inflating: stocks/2019/11/06/stocks.csv
#   inflating: stocks/2019/11/07/stocks.csv
#   inflating: stocks/2019/11/08/stocks.csv
#   inflating: stocks/2019/11/11/stocks.csv
#   inflating: stocks/2019/11/12/stocks.csv
#   inflating: stocks/2019/11/13/stocks.csv
#   inflating: stocks/2019/11/14/stocks.csv
#   inflating: stocks/2019/11/15/stocks.csv
#   inflating: stocks/2019/11/18/stocks.csv
#   inflating: stocks/2019/11/19/stocks.csv
#   inflating: stocks/2019/11/20/stocks.csv
#   inflating: stocks/2019/11/21/stocks.csv
#   inflating: stocks/2019/11/22/stocks.csv
#   inflating: stocks/2019/11/25/stocks.csv
#   inflating: stocks/2019/11/26/stocks.csv
#   inflating: stocks/2019/11/27/stocks.csv
#   inflating: stocks/2019/11/29/stocks.csv
#   inflating: stocks/2019/12/02/stocks.csv
#   inflating: stocks/2019/12/03/stocks.csv
#   inflating: stocks/2019/12/04/stocks.csv
#   inflating: stocks/2019/12/05/stocks.csv
#   inflating: stocks/2019/12/06/stocks.csv
#   inflating: stocks/2019/12/09/stocks.csv
#   inflating: stocks/2019/12/10/stocks.csv
#   inflating: stocks/2019/12/11/stocks.csv
#   inflating: stocks/2019/12/12/stocks.csv
#   inflating: stocks/2019/12/13/stocks.csv
#   inflating: stocks/2019/12/16/stocks.csv
#   inflating: stocks/2019/12/17/stocks.csv
#   inflating: stocks/2019/12/18/stocks.csv
#   inflating: stocks/2019/12/19/stocks.csv
#   inflating: stocks/2019/12/20/stocks.csv
#   inflating: stocks/2019/12/23/stocks.csv
#   inflating: stocks/2019/12/24/stocks.csv
#   inflating: stocks/2019/12/26/stocks.csv
#   inflating: stocks/2019/12/27/stocks.csv
#   inflating: stocks/2019/12/30/stocks.csv
#   inflating: stocks/2019/12/31/stocks.csv
#   inflating: stocks/2019/01/02/stocks.csv
#   inflating: stocks/2019/01/03/stocks.csv
#   inflating: stocks/2019/01/04/stocks.csv
#   inflating: stocks/2019/01/07/stocks.csv
#   inflating: stocks/2019/01/08/stocks.csv
#   inflating: stocks/2019/01/09/stocks.csv
#   inflating: stocks/2019/01/10/stocks.csv
#   inflating: stocks/2019/01/11/stocks.csv
#   inflating: stocks/2019/01/14/stocks.csv
#   inflating: stocks/2019/01/15/stocks.csv
#   inflating: stocks/2019/01/16/stocks.csv
#   inflating: stocks/2019/01/17/stocks.csv
#   inflating: stocks/2019/01/18/stocks.csv
#   inflating: stocks/2019/01/22/stocks.csv
#   inflating: stocks/2019/01/23/stocks.csv
#   inflating: stocks/2019/01/24/stocks.csv
#   inflating: stocks/2019/01/25/stocks.csv
#   inflating: stocks/2019/01/28/stocks.csv
#   inflating: stocks/2019/01/29/stocks.csv
#   inflating: stocks/2019/01/30/stocks.csv
#   inflating: stocks/2019/01/31/stocks.csv
#   inflating: stocks/2019/02/01/stocks.csv
#   inflating: stocks/2019/02/04/stocks.csv
#   inflating: stocks/2019/02/05/stocks.csv
#   inflating: stocks/2019/02/06/stocks.csv
#   inflating: stocks/2019/02/07/stocks.csv
#   inflating: stocks/2019/02/08/stocks.csv
#   inflating: stocks/2019/02/11/stocks.csv
#   inflating: stocks/2019/02/12/stocks.csv
#   inflating: stocks/2019/02/13/stocks.csv
#   inflating: stocks/2019/02/14/stocks.csv
#   inflating: stocks/2019/02/15/stocks.csv
#   inflating: stocks/2019/02/19/stocks.csv
#   inflating: stocks/2019/02/20/stocks.csv
#   inflating: stocks/2019/02/21/stocks.csv
#   inflating: stocks/2019/02/22/stocks.csv
#   inflating: stocks/2019/02/25/stocks.csv
#   inflating: stocks/2019/02/26/stocks.csv
#   inflating: stocks/2019/02/27/stocks.csv
#   inflating: stocks/2019/02/28/stocks.csv
#   inflating: stocks/2019/03/11/stocks.csv
#   inflating: stocks/2019/03/12/stocks.csv
#   inflating: stocks/2019/03/13/stocks.csv
#   inflating: stocks/2019/03/14/stocks.csv
#   inflating: stocks/2019/03/15/stocks.csv
#   inflating: stocks/2019/03/18/stocks.csv
#   inflating: stocks/2019/03/19/stocks.csv
#   inflating: stocks/2019/03/20/stocks.csv
#   inflating: stocks/2019/03/21/stocks.csv
#   inflating: stocks/2019/03/22/stocks.csv
#   inflating: stocks/2019/03/25/stocks.csv
#   inflating: stocks/2019/03/26/stocks.csv
#   inflating: stocks/2019/03/27/stocks.csv
#   inflating: stocks/2019/03/28/stocks.csv
#   inflating: stocks/2019/03/29/stocks.csv
#   inflating: stocks/2019/03/01/stocks.csv
#   inflating: stocks/2019/03/04/stocks.csv
#   inflating: stocks/2019/03/05/stocks.csv
#   inflating: stocks/2019/03/06/stocks.csv
#   inflating: stocks/2019/03/07/stocks.csv
#   inflating: stocks/2019/03/08/stocks.csv
#   inflating: stocks/2019/04/02/stocks.csv
#   inflating: stocks/2019/04/03/stocks.csv
#   inflating: stocks/2019/04/04/stocks.csv
#   inflating: stocks/2019/04/05/stocks.csv
#   inflating: stocks/2019/04/08/stocks.csv
#   inflating: stocks/2019/04/09/stocks.csv
#   inflating: stocks/2019/04/10/stocks.csv
#   inflating: stocks/2019/04/11/stocks.csv
#   inflating: stocks/2019/04/12/stocks.csv
#   inflating: stocks/2019/04/15/stocks.csv
#   inflating: stocks/2019/04/16/stocks.csv
#   inflating: stocks/2019/04/17/stocks.csv
#   inflating: stocks/2019/04/18/stocks.csv
#   inflating: stocks/2019/04/22/stocks.csv
#   inflating: stocks/2019/04/23/stocks.csv
#   inflating: stocks/2019/04/24/stocks.csv
#   inflating: stocks/2019/04/25/stocks.csv
#   inflating: stocks/2019/04/26/stocks.csv
#   inflating: stocks/2019/04/29/stocks.csv
#   inflating: stocks/2019/04/30/stocks.csv
#   inflating: stocks/2019/04/01/stocks.csv
#   inflating: stocks/2020/04/01/stocks.csv
#   inflating: stocks/2020/04/02/stocks.csv
#   inflating: stocks/2020/01/02/stocks.csv
#   inflating: stocks/2020/01/03/stocks.csv
#   inflating: stocks/2020/01/06/stocks.csv
#   inflating: stocks/2020/01/07/stocks.csv
#   inflating: stocks/2020/01/08/stocks.csv
#   inflating: stocks/2020/01/09/stocks.csv
#   inflating: stocks/2020/01/10/stocks.csv
#   inflating: stocks/2020/01/13/stocks.csv
#   inflating: stocks/2020/01/14/stocks.csv
#   inflating: stocks/2020/01/15/stocks.csv
#   inflating: stocks/2020/01/16/stocks.csv
#   inflating: stocks/2020/01/17/stocks.csv
#   inflating: stocks/2020/01/21/stocks.csv
#   inflating: stocks/2020/01/22/stocks.csv
#   inflating: stocks/2020/01/23/stocks.csv
#   inflating: stocks/2020/01/24/stocks.csv
#   inflating: stocks/2020/01/27/stocks.csv
#   inflating: stocks/2020/01/28/stocks.csv
#   inflating: stocks/2020/01/29/stocks.csv
#   inflating: stocks/2020/01/30/stocks.csv
#   inflating: stocks/2020/01/31/stocks.csv
#   inflating: stocks/2020/02/03/stocks.csv
#   inflating: stocks/2020/02/04/stocks.csv
#   inflating: stocks/2020/02/05/stocks.csv
#   inflating: stocks/2020/02/06/stocks.csv
#   inflating: stocks/2020/02/07/stocks.csv
#   inflating: stocks/2020/02/10/stocks.csv
#   inflating: stocks/2020/02/11/stocks.csv
#   inflating: stocks/2020/02/12/stocks.csv
#   inflating: stocks/2020/02/13/stocks.csv
#   inflating: stocks/2020/02/14/stocks.csv
#   inflating: stocks/2020/02/18/stocks.csv
#   inflating: stocks/2020/02/19/stocks.csv
#   inflating: stocks/2020/02/20/stocks.csv
#   inflating: stocks/2020/02/21/stocks.csv
#   inflating: stocks/2020/02/24/stocks.csv
#   inflating: stocks/2020/02/25/stocks.csv
#   inflating: stocks/2020/02/26/stocks.csv
#   inflating: stocks/2020/02/27/stocks.csv
#   inflating: stocks/2020/02/28/stocks.csv
#   inflating: stocks/2020/03/26/stocks.csv
#   inflating: stocks/2020/03/27/stocks.csv
#   inflating: stocks/2020/03/30/stocks.csv
#   inflating: stocks/2020/03/31/stocks.csv
#   inflating: stocks/2020/03/02/stocks.csv
#   inflating: stocks/2020/03/03/stocks.csv
#   inflating: stocks/2020/03/04/stocks.csv
#   inflating: stocks/2020/03/05/stocks.csv
#   inflating: stocks/2020/03/06/stocks.csv
#   inflating: stocks/2020/03/09/stocks.csv
#   inflating: stocks/2020/03/10/stocks.csv
#   inflating: stocks/2020/03/11/stocks.csv
#   inflating: stocks/2020/03/12/stocks.csv
#   inflating: stocks/2020/03/13/stocks.csv
#   inflating: stocks/2020/03/16/stocks.csv
#   inflating: stocks/2020/03/17/stocks.csv
#   inflating: stocks/2020/03/18/stocks.csv
#   inflating: stocks/2020/03/19/stocks.csv
#   inflating: stocks/2020/03/20/stocks.csv
#   inflating: stocks/2020/03/23/stocks.csv
#   inflating: stocks/2020/03/24/stocks.csv
#   inflating: stocks/2020/03/25/stocks.csv

# %% [markdown]
# > ## 🚩️ Important Notice 🚩️
# >
# >To successfully run `pydeequ` without any errors, please make sure that you have an environment that is running pyspark version 3.0.
# > You are advised to **create a new conda environment** and install this specific version of pyspark to avoid any technical issues:
# >
# > `pip install pyspark==3.0`
#
# <br>
#
# ## Import dependencies
#
# If you do not have `pydeequ` already installed, install it using the following command:
# - `pip install pydeequ`

# %%
# !pip install pydeequ
# Out:
# Requirement already satisfied: pydeequ in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from pydeequ) (1.23.5)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from pydeequ) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->pydeequ) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->pydeequ) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.23.0->pydeequ) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pydeequ
from pydeequ.analyzers import *
from pydeequ.profiles import *
from pydeequ.suggestions import *
from pydeequ.checks import *
from pydeequ.verification import *
from pydeequ.verification import VerificationSuite
from pydeequ.checks import Check, CheckLevel

from pyspark.sql.functions import col
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import DecimalType, DoubleType, IntegerType, DateType, NumericType, StructType, StringType, StructField

# %%
spark = (SparkSession.builder.master("local")
.appName("Colab")
.config('spark.ui.port', '4050')
.config("spark.jars.packages", pydeequ.deequ_maven_coord)
.config("spark.jars.excludes", pydeequ.f2j_maven_coord).getOrCreate())

# %% [markdown]
# ## Read data into spark dataframe
#
# In this notebook, we set out to run some data quality tests, with the possiblity of running end to end on the years 1963, 1974, 1985, 1996, 2007, and 2018.
#
# > ℹ️ **Instructions** ℹ️
# >
# >1. Make use of the `Data_ingestion_student_version.ipynb` notebook to create the parquet files for the following years:
# >       - 1963
# >       - 1974
# >       - 1985
# >       - 1996
# >       - 2007
# >       - 2018
# >
# >2. Ingest the data for the for the years given above. You should only do it one year at a time.
# >3. Ingest the metadata file.
#
#
# When developing your code, it will be sufficient to focus on a single year. However, after your development is done, you will need to run this notebook for all of the given years above so that you can answer all the questions given in the Data Testing MCQ.

# %%
#TODO: Write your code here
year = 1963
# Define the data schema with string data types
data_schema = StructType([
    StructField("date", StringType(), True),
    StructField("open", StringType(), True),
    StructField("high", StringType(), True),
    StructField("low", StringType(), True),
    StructField("close", StringType(), True),
    StructField("adj_close", StringType(), True),
    StructField("volume", StringType(), True),
])

# Path to the CSV files for the year 1963
data_path_1963 = "/content/stocks/1963/*/*/*"


# Read in the data for 2018 with the specified schema
data_1963 = spark.read.csv(data_path_1963, schema=data_schema)

# Show the first few rows of the DataFrame
data_1963.show()
# Out:
# +----------+-------------------+-------------------+-------------------+-------------------+--------------------+---------+
# |      date|               open|               high|                low|              close|           adj_close|   volume|
# +----------+-------------------+-------------------+-------------------+-------------------+--------------------+---------+
# |      Date|               Open|               High|                Low|              Close|           Adj Close|   Volume|
# |1963-10-28|  6.924644947052003|  6.940664768218994|   6.90862512588501|   6.90862512588501|  1.6844346523284912|  39900.0|
# |1963-10-28|  6.488943099975586|  6.512368679046631|  6.465517044067383|  6.465517044067383|  1.5472991466522217|  42600.0|
# |1963-10-28| 0.5679012537002563| 0.5699588656425476| 0.5617284178733826| 0.5699588656425476| 0.11004561930894853| 789600.0|
# |1963-10-28| 1.8541666269302368| 1.9166666269302368| 1.8541666269302368| 1.9166666269302368| 0.17308039963245392| 319200.0|
# |1963-10-28|                0.0|          4.0859375|          4.0234375|           4.046875| 0.06761479377746582| 156800.0|
# |1963-10-28|0.11303646117448808|0.11464209109544755|0.11303646117448808|0.11303646117448808| 0.04413221776485443|1012000.0|
# |1963-10-28|                0.0|               32.5|             32.125|               32.5|  0.5788508653640747|   8400.0|
# |1963-10-28|                0.0|          10.671875|          10.609375|          10.609375| 0.25488758087158203|  36000.0|
# |1963-10-28|                0.0|  6.229166507720947|  6.166666507720947|  6.229166507720947|  0.8584017753601074|  39600.0|
# |1963-10-28|  0.807542085647583| 0.8313301205635071|  0.807542085647583| 0.8313301205635071|0.002073692390695...|3434400.0|
# |1963-10-28|                0.0|           10.78125|           10.65625|           10.65625|   1.945993423461914|  34800.0|
# |1963-10-28|0.07450613379478455|0.07539311051368712|0.07406264543533325|0.07494962215423584|0.004156964365392...|1860200.0|
# |1963-10-28|  6.613333225250244|  6.690000057220459|  6.613333225250244|  6.630000114440918|  0.5381157398223877|1848000.0|
# |1963-10-28|                0.0|  8.413461685180664|  8.290187835693361|  8.321005821228027|  0.7747041583061218|  33200.0|
# |1963-10-28|                0.0| 0.2690972089767456| 0.2563657462596893|0.25665509700775146|7.378940267699363...|2030400.0|
# |1963-10-28| 0.2727864682674408| 0.2760416567325592| 0.2727864682674408| 0.2760416567325592| 0.00467178737744689|1651200.0|
# |1963-10-28|                0.0| 0.1349826455116272| 0.1323784738779068| 0.1338975727558136|0.000177902853465...|1670400.0|
# |1963-10-28|                0.0|            306.875|             303.75|             303.75|  146.98666381835938|   1100.0|
# |1963-10-28|                0.0|          1.2578125|           1.234375|        1.244140625|0.012249606661498548| 198400.0|
# +----------+-------------------+-------------------+-------------------+-------------------+--------------------+---------+
# only showing top 20 rows

# %%
import zipfile
# TODO: Replace with the actual path to parquet files
parquet_path = "/content/drive/MyDrive/parquet/stocks_1963.zip"
# Replace "/content/drive/MyDrive/parquet/stocks_1963.zip" with the actual path to zipped Parquet file
zipped_parquet_path = "/content/drive/MyDrive/parquet/stocks_1963.zip"
unzipped_parquet_path = "/content/drive/MyDrive/parquet/unzipped_stocks_1963"

# Create a directory to extract the contents
os.makedirs(unzipped_parquet_path, exist_ok=True)

# Unzip the Parquet file
with zipfile.ZipFile(zipped_parquet_path, 'r') as zip_ref:
    zip_ref.extractall(unzipped_parquet_path)

# List the contents of the Parquet directory
contents = os.listdir('/content/drive/MyDrive/parquet/unzipped_stocks_1963/content/stocks_1963.parquet')
print("Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_1963/content/stocks_1963.parquet:")
for item in contents:
    print(item)
# Out:
# Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_1963/content/stocks_1963.parquet:
# part-00000-85891194-ff25-46fe-b327-ddb300e72116-c000.snappy.parquet
# .part-00000-85891194-ff25-46fe-b327-ddb300e72116-c000.snappy.parquet.crc
# ._SUCCESS.crc
# _SUCCESS
# part-00001-85891194-ff25-46fe-b327-ddb300e72116-c000.snappy.parquet
# .part-00001-85891194-ff25-46fe-b327-ddb300e72116-c000.snappy.parquet.crc

# %%
#Ingest Metadata
from pyspark import SparkFiles
# Download metadata and make it available to Spark
spark.sparkContext.addFile("https://processing-big-data-predict-stocks-data.s3.eu-west-1.amazonaws.com/symbols_valid_meta.csv")
# Specify the correct path to the metadata file
metadata_path_pbd = "file://" + SparkFiles.get("symbols_valid_meta.csv")
# Read metadata into Spark DataFrame
metadata_df_pbd = spark.read.csv(metadata_path_pbd, header=True)

# Show the metadata DataFrame
metadata_df_pbd.show()
# Out:
# +-------------+------+--------------------+----------------+---------------+---+--------------+----------+----------------+----------+-------------+----------+
# |Nasdaq Traded|Symbol|       Security Name|Listing Exchange|Market Category|ETF|Round Lot Size|Test Issue|Financial Status|CQS Symbol|NASDAQ Symbol|NextShares|
# +-------------+------+--------------------+----------------+---------------+---+--------------+----------+----------------+----------+-------------+----------+
# |            Y|     A|Agilent Technolog...|               N|               |  N|         100.0|         N|            null|         A|            A|         N|
# |            Y|    AA|Alcoa Corporation...|               N|               |  N|         100.0|         N|            null|        AA|           AA|         N|
# |            Y|  AAAU|Perth Mint Physic...|               P|               |  Y|         100.0|         N|            null|      AAAU|         AAAU|         N|
# |            Y|  AACG|ATA Creativity Gl...|               Q|              G|  N|         100.0|         N|               N|      null|         AACG|         N|
# |            Y|  AADR|AdvisorShares Dor...|               P|               |  Y|         100.0|         N|            null|      AADR|         AADR|         N|
# |            Y|   AAL|American Airlines...|               Q|              Q|  N|         100.0|         N|               N|      null|          AAL|         N|
# |            Y|  AAMC|Altisource Asset ...|               A|               |  N|         100.0|         N|            null|      AAMC|         AAMC|         N|
# |            Y|  AAME|Atlantic American...|               Q|              G|  N|         100.0|         N|               N|      null|         AAME|         N|
# |            Y|   AAN|Aaron's, Inc. Com...|               N|               |  N|         100.0|         N|            null|       AAN|          AAN|         N|
# |            Y|  AAOI|Applied Optoelect...|               Q|              G|  N|         100.0|         N|               N|      null|         AAOI|         N|
# |            Y|  AAON|AAON, Inc. - Comm...|               Q|              Q|  N|         100.0|         N|               N|      null|         AAON|         N|
# |            Y|   AAP|Advance Auto Part...|               N|               |  N|         100.0|         N|            null|       AAP|          AAP|         N|
# |            Y|  AAPL|Apple Inc. - Comm...|               Q|              Q|  N|         100.0|         N|               N|      null|         AAPL|         N|
# |            Y|   AAT|American Assets T...|               N|               |  N|         100.0|         N|            null|       AAT|          AAT|         N|
# |            Y|   AAU|Almaden Minerals,...|               A|               |  N|         100.0|         N|            null|       AAU|          AAU|         N|
# |            Y|  AAWW|Atlas Air Worldwi...|               Q|              Q|  N|         100.0|         N|               N|      null|         AAWW|         N|
# |            Y|  AAXJ|iShares MSCI All ...|               Q|              G|  Y|         100.0|         N|               N|      null|         AAXJ|         N|
# |            Y|  AAXN|Axon Enterprise, ...|               Q|              Q|  N|         100.0|         N|               N|      null|         AAXN|         N|
# |            Y|    AB|AllianceBernstein...|               N|               |  N|         100.0|         N|            null|        AB|           AB|         N|
# |            Y|   ABB|ABB Ltd Common Stock|               N|               |  N|         100.0|         N|            null|       ABB|          ABB|         N|
# +-------------+------+--------------------+----------------+---------------+---+--------------+----------+----------------+----------+-------------+----------+
# only showing top 20 rows

# %% [markdown]
# ## **Run tests on the dataset**
#
# ## Test 1 - Null values ⛔️
# For the first test, you are required to check the data for completeness.
#
# > ℹ️ **Instructions** ℹ️
# >
# >1. Make use of the `Verification Suite` and write code to check for missing values in the data.
# >2. Display the results of your test.
# >
# > *You may use as many cells as necessary*

# %%
# Test 1 - Null values using Deequ Verification Suite
for col_name in data_1963.columns:
    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Null check for column {col_name}") \
        .isComplete(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_1963).addCheck(check).run()

    # Display the results of the check for each column
    print(f"Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Null Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %% [markdown]
# ## Test 2 - Zero Values 🅾️
#
# For the second test, you are required to check for zero values within the dataset.
#
# > ℹ️ **Instructions** ℹ️
# >
# >1. Make use of the `Verification Suite` and write code to check for zero values within the data.
# >2. Display the results of your test.
# >
# > *You may use as many cells as necessary*

# %%
# Test 2 - Zero values using Deequ Verification Suite
for col_name in data_1963.columns:
    # Convert column values to string for Zero check
    data_1963_str = data_1963.withColumn(col_name, F.col(col_name).cast("string"))

    # Define a Check for each column for Zero values
    zero_check = Check(spark, level=CheckLevel.Error, description=f"Zero values check for column {col_name}") \
        .isComplete(col_name)

    # Run Zero check
    zero_result = VerificationSuite(spark).onData(data_1963_str).addCheck(zero_check).run()

    # Display the results of the Zero check for each column
    print(f"Zero Values Check for Column {col_name}:")
    print(f"  - Has errors: {zero_result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in zero_result.checkResults[0]:
        print(f"  - Number of errors: {zero_result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in zero_result.checkResults[0]:
        print(f"  - Error details: {zero_result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Zero Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test - Zero values using Deequ Verification Suite for metadata_df_pbd
for col_name in metadata_df_pbd.columns:
    # Convert column values to string for Zero check
    metadata_df_pbd_str = metadata_df_pbd.withColumn(col_name, F.col(col_name).cast("string"))

    # Define a Check for each column for Zero values
    zero_check = Check(spark, level=CheckLevel.Error, description=f"Zero values check for column {col_name}") \
        .hasSize(lambda x: x > 0, "Zero values check")

    # Run Zero check
    zero_result = VerificationSuite(spark).onData(metadata_df_pbd_str).addCheck(zero_check).run()

    # Display the results of the Zero check for each column
    print(f"Zero Values Check for Column {col_name} in metadata_df_pbd:")
    print(f"  - Has errors: {zero_result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in zero_result.checkResults[0]:
        print(f"  - Number of errors: {zero_result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in zero_result.checkResults[0]:
        print(f"  - Error details: {zero_result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Zero Values Check for Column Nasdaq Traded in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column Symbol in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column Security Name in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column Listing Exchange in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column Market Category in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column ETF in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column Round Lot Size in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column Test Issue in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column Financial Status in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column CQS Symbol in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column NASDAQ Symbol in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column NextShares in metadata_df_pbd:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %% [markdown]
# ## Test 3 - Negative values ➖️
# The third test requires you to check that all values in the data are positive.
#
# > ℹ️ **Instructions** ℹ️
# >
# >1. Make use of the `Verification Suite` and write code to check negative values within the dataset.
# >2. Display the results of your test.
# >
# > *You may use as many cells as necessary*

# %%
# Test 3 - Negative values using Deequ Verification Suite
table_negative_values = []

for col_name in data_1963.columns:
    # Convert column values to string
    data_1963_str = data_1963.withColumn(col_name, col(col_name).cast("string"))

    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Negative check for column {col_name}") \
        .isNonNegative(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_1963_str).addCheck(check).run()

    # Display the results of the Negative check for each column
    print(f"Negative Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Negative Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
from pyspark.sql.functions import col

# List of columns to check
columns_to_check = ["Nasdaq Traded", "Security Name", "Listing Exchange", "Market Category",
                    "Round Lot Size", "Test Issue", "Financial Status", "CQS Symbol",
                    "NASDAQ Symbol", "NextShares"]

# Check minimum values for each column
for col_name in columns_to_check:
    min_value = metadata_df_pbd.selectExpr(f"min(`{col_name}`) as min_value").collect()[0]["min_value"]
    print(f"Minimum value for column {col_name}: {min_value}")
# Out:
# Minimum value for column Nasdaq Traded: Y
# Minimum value for column Security Name: 1-800-FLOWERS.COM, Inc. - Class A Common Stock
# Minimum value for column Listing Exchange: A
# Minimum value for column Market Category:
# Minimum value for column Round Lot Size: 1.0
# Minimum value for column Test Issue: N
# Minimum value for column Financial Status: D
# Minimum value for column CQS Symbol: A
# Minimum value for column NASDAQ Symbol: A
# Minimum value for column NextShares: N

# %% [markdown]
# ## Test 4 - Determine Maximum Values ⚠️
#
# For the fourth test, we want to find the maximum values in the dataset for the numerical fields. Extremum values can often be used to define an upper bound for the column values so we can define them as the threshold values.
#
# > ℹ️ **Instructions** ℹ️
# >
# >1. Make use of the `Column Profiler Runner` to generate summary statistics for all the available columns.
# >2. Extract the maximum values for all the numeric columns in the data.
# >
# > *You may use as many cells as necessary*

# %%
from pydeequ.profiles import ColumnProfilerRunner
from pyspark.sql import SparkSession
#Test 4
# Create a Spark session
spark = SparkSession.builder.appName("MaxValuesTest").getOrCreate()

# Load data
data_path = "/content/drive/MyDrive/parquet/unzipped_stocks_1963/content/stocks_1963.parquet"
data_1963 = spark.read.parquet(data_path)

# Use Column Profiler Runner to generate summary statistics
column_profiles = ColumnProfilerRunner(spark) \
    .onData(data_1963) \
    .run()

# Extract maximum values for all numeric columns
max_values = {}

for col_name, profile in column_profiles.profiles.items():
    if profile.dataType == "Integral" or profile.dataType == "Fractional":
        max_values[col_name] = profile.maximum

# Display the maximum values
print("Maximum Values for Numeric Columns:")
for col_name, max_value in max_values.items():
    print(f"{col_name}: {max_value}")
# Out:
# Maximum Values for Numeric Columns:
# open: 303.125
# low: 311.875
# close: 313.75
# volume: 20692800.0
# adj_close: 148.7704620361328
# high: 315.625

# %% [markdown]
# ## Test 5 - Stock Tickers 💹️
#
# For the fifth test, we want to determine if the stock tickers contained in our dataset are consistent. To do this, you will need to make use of use of the metadata file to check that the stock names used in the dataframe are valid.
#
# > ℹ️ **Instructions** ℹ️
# >
# >1. Make use of the `Verification Suite` and write code to determine if the stock tickers contained in the dataset appear in the metadata file.
# >2. Display the results of your test.
# >
# > *You may use as many cells as necessary*

# %%
from pydeequ.verification import VerificationSuite
from pyspark.sql.functions import col

# Assuming the column containing stock tickers is named 'Symbol' in metadata_df_pbd
stock_ticker_col = 'Symbol'

# Extract distinct stock tickers from the metadata
distinct_stock_tickers_metadata = metadata_df_pbd.select(col(stock_ticker_col)).distinct()

# Convert the distinct stock tickers to a list
distinct_tickers_list_metadata = [row[stock_ticker_col] for row in distinct_stock_tickers_metadata.collect()]

# Define a check to verify if stock tickers appear in the metadata
ticker_check = Check(spark, level=CheckLevel.Warning, description="Stock Ticker check") \
    .isContainedIn(stock_ticker_col, distinct_tickers_list_metadata)

# Run the check using the Verification Suite
verification_result = VerificationSuite(spark).onData(metadata_df_pbd).addCheck(ticker_check).run()

# Display the results of the stock ticker check
print("Stock Ticker Check Results:")
print(f"  - Has warnings: {verification_result.status == 'Warning'}")

# Check if there are warnings before trying to access the number of warnings
if 'numRecordsFailed' in verification_result.checkResults[0]:
    print(f"  - Number of warnings: {verification_result.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of warnings: 0")

# Check if 'constraintMessage' is present before accessing it
if 'constraintMessage' in verification_result.checkResults[0]:
    print(f"  - Warning details: {verification_result.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Warning details: No constraint message available\n")
# Out:
# Stock Ticker Check Results:
#   - Has warnings: False
#   - Number of warnings: 0
#   - Warning details: No constraint message available

# %% [markdown]
# ## Test 6 - Duplication 👥️
# Lastly, we want to determine the uniqueness of the items found in the dataframe. You need to make use of the Verification Suite to check for the validity of the stock tickers.
#
# Similar to the previous notebook - `Data_profiling_student_version.ipynb`, the first thing to check will be if the primary key values within the dataset are unique - in our case, that will be a combination of the stock name and the date. Secondly, we want to check if the entries are all unique, which is done by checking for duplicates across that whole dataset.
#
# > ℹ️ **Instructions** ℹ️
# >
# >1. Make use of the `Verification Suite` and write code to determine the uniqueness of entries contained within the dataset.
# >2. Display the results of your test.
# >
# > *You may use as many cells as necessary*

# %%
# Specify the column to check
col_name = 'date'

# Investigate duplicate values in the 'date' column
data_1963.groupBy("date").count().filter("count > 1").show()

# Remove duplicate rows based on the 'date' column
data_1963 = data_1963.dropDuplicates(["date"])


# Check for uniqueness in data_1963 based on the 'date' column
unique_check_data_1963_column = Check(spark, level=CheckLevel.Error, description=f"Uniqueness check for {col_name}") \
    .isUnique(col_name)

# Check for general duplicates in data_1963 for the 'date' column
duplicate_check_data_1963_column = Check(spark, level=CheckLevel.Error,
                                          description=f"Duplicate check for {col_name}") \
    .hasSize(lambda x: x == data_1963.select(col_name).distinct().count(),
             f"Duplicate check for {col_name}")

# Run checks for the 'date' column using the Verification Suite
verification_result_data_1963_column = VerificationSuite(spark) \
    .onData(data_1963) \
    .addCheck(unique_check_data_1963_column) \
    .addCheck(duplicate_check_data_1963_column) \
    .run()

# Display results for the 'date' column
print(f"\nVerification Results for column {col_name} in data_1963:")
print(f"  - Has errors: {verification_result_data_1963_column.status == 'Error'}")
print(f"  - Number of uniqueness errors: {verification_result_data_1963_column.checkResults[0]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1963_column.checkResults[0] else "0")
print(f"  - Number of duplicate errors: {verification_result_data_1963_column.checkResults[1]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1963_column.checkResults[1] else "0")
print(f"  - Uniqueness error details: {verification_result_data_1963_column.checkResults[0]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1963_column.checkResults[0] else "No constraint message available")
print(f"  - Duplicate error details: {verification_result_data_1963_column.checkResults[1]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1963_column.checkResults[1] else "No constraint message available")

# Print the content of the column with errors
if verification_result_data_1963_column.status == 'Error':
    print(f"  - Content of the column with errors for {col_name}:")
    for check_result in verification_result_data_1963_column.checkResults:
        print(check_result)
# Out:
# Verification Results for column date in data_1963:
#   - Has errors: False
# 0
# 0
# No constraint message available
# No constraint message available

# %%
# Specify the column to check
col_name = 'date'

# Check for uniqueness in data_1963 based on the 'date' column
unique_check_data_1963_column = Check(spark, level=CheckLevel.Error, description=f"Uniqueness check for {col_name}") \
    .isUnique(col_name)

# Check for general duplicates in data_1963 for the 'date' column
duplicate_check_data_1963_column = Check(spark, level=CheckLevel.Error,
                                          description=f"Duplicate check for {col_name}") \
    .hasSize(lambda x: x == data_1963.select(col_name).distinct().count(),
             f"Duplicate check for {col_name}")

# Run checks for the 'date' column using the Verification Suite
verification_result_data_1963_column = VerificationSuite(spark) \
    .onData(data_1963) \
    .addCheck(unique_check_data_1963_column) \
    .addCheck(duplicate_check_data_1963_column) \
    .run()

# Display results for the 'date' column
print(f"\nVerification Results for column {col_name} in data_1963:")
print(f"  - Has errors: {verification_result_data_1963_column.status == 'Error'}")
print(f"  - Number of uniqueness errors: {verification_result_data_1963_column.checkResults[0]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1963_column.checkResults[0] else "0")
print(f"  - Number of duplicate errors: {verification_result_data_1963_column.checkResults[1]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1963_column.checkResults[1] else "0")
print(f"  - Uniqueness error details: {verification_result_data_1963_column.checkResults[0]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1963_column.checkResults[0] else "No constraint message available")
print(f"  - Duplicate error details: {verification_result_data_1963_column.checkResults[1]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1963_column.checkResults[1] else "No constraint message available")

# Print the content of the column with errors
if verification_result_data_1963_column.status == 'Error':
    print(f"  - Content of the column with errors for {col_name}:")
    for check_result in verification_result_data_1963_column.checkResults:
        print(check_result)
# Out:
# Verification Results for column date in data_1963:
#   - Has errors: False
# 0
# 0
# No constraint message available
# No constraint message available

# %%
# Assuming 'Symbol' is the column representing stock tickers in metadata_df_pbd
stock_ticker_col_metadata = 'Symbol'

# Check for uniqueness in metadata_df_pbd based on 'Symbol'
unique_check_metadata = Check(spark, level=CheckLevel.Error, description="Uniqueness check for stock tickers") \
    .isUnique(stock_ticker_col_metadata)

# Check for general duplicates in metadata_df_pbd
duplicate_check_metadata = Check(spark, level=CheckLevel.Error, description="Duplicate check for entire metadata") \
    .hasSize(lambda x: x == metadata_df_pbd.count(), "Duplicate check for entire metadata")

# Run both checks using the Verification Suite
verification_result_metadata = VerificationSuite(spark) \
    .onData(metadata_df_pbd) \
    .addCheck(unique_check_metadata) \
    .addCheck(duplicate_check_metadata) \
    .run()

# Display the results of the checks for metadata_df_pbd
print("Verification Results for metadata_df_pbd:")
print(f"  - Has errors: {verification_result_metadata.status == 'Error'}")

# Check if there are errors in the uniqueness check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[0]:
    print(f"  - Number of uniqueness errors: {verification_result_metadata.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of uniqueness errors: 0")

# Check if there are errors in the duplicate check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[1]:
    print(f"  - Number of duplicate errors: {verification_result_metadata.checkResults[1]['numRecordsFailed']}")
else:
    print("  - Number of duplicate errors: 0")

# Check if 'constraintMessage' is present before accessing it for uniqueness check
if 'constraintMessage' in verification_result_metadata.checkResults[0]:
    print(f"  - Uniqueness error details: {verification_result_metadata.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Uniqueness error details: No constraint message available\n")

# Check if 'constraintMessage' is present before accessing it for duplicate check
if 'constraintMessage' in verification_result_metadata.checkResults[1]:
    print(f"  - Duplicate error details: {verification_result_metadata.checkResults[1]['constraintMessage']}\n")
else:
    print("  - Duplicate error details: No constraint message available\n")
# Out:
# Verification Results for metadata_df_pbd:
#   - Has errors: False
#   - Number of uniqueness errors: 0
#   - Number of duplicate errors: 0
#   - Uniqueness error details: No constraint message available
#
#   - Duplicate error details: No constraint message available

# %% [markdown]
# **YEAR 1974**

# %%
#TODO: Write your code here
year = 1974
# Define the data schema with string data types
data_schema = StructType([
    StructField("date", StringType(), True),
    StructField("open", StringType(), True),
    StructField("high", StringType(), True),
    StructField("low", StringType(), True),
    StructField("close", StringType(), True),
    StructField("adj_close", StringType(), True),
    StructField("volume", StringType(), True),
])

# Path to the CSV files for the year 1963
data_path_1974 = "/content/stocks/1974/*/*/*"


# Read in the data for 2018 with the specified schema
data_1974 = spark.read.csv(data_path_1974, schema=data_schema)

# Show the first few rows of the DataFrame
data_1974.show()
# Out:
# +----------+-------------------+------------------+-------------------+-------------------+--------------------+---------+
# |      date|               open|              high|                low|              close|           adj_close|   volume|
# +----------+-------------------+------------------+-------------------+-------------------+--------------------+---------+
# |      Date|               Open|              High|                Low|              Close|           Adj Close|   Volume|
# |1974-11-06|  4.980217456817627| 5.040292263031006|  4.818015098571777| 4.8300299644470215|  1.5678892135620115| 173000.0|
# |1974-11-06|                0.0|             7.875|              7.625|              7.625|   5.073933124542236|  25400.0|
# |1974-11-06|              16.25|            16.625|             16.125|             16.375|  0.6937137842178345|  48600.0|
# |1974-11-06| 15.372641563415527|15.372641563415527| 15.372641563415527| 15.372641563415527|    10.8353910446167|      0.0|
# |1974-11-06|                2.0|           2.03125|            1.90625|            1.90625|  0.9735426902770996|   3600.0|
# |1974-11-06|           10.78125|            10.875|           10.78125|           10.78125|  2.1408343315124507|    400.0|
# |1974-11-06|                0.0|               3.0|              2.625|              2.625|  1.1026287078857422|    900.0|
# |1974-11-06|              6.375|             6.375|              6.375|              6.375|  2.4823830127716064|      0.0|
# |1974-11-06|0.14079999923706055|0.1728000044822693|0.14079999923706055|0.14079999923706055| 0.07081376016139984|    200.0|
# |1974-11-06|  4.673444747924805| 4.761291027069092|  4.515320301055908| 4.5328898429870605|  1.4431884288787842| 184800.0|
# |1974-11-06|                0.0|            8.5625|             8.4375|             8.5625|  0.6195887327194214|   2000.0|
# |1974-11-06| 1.3068181276321411|1.3352272510528564|  1.278409123420715|  1.278409123420715|  0.8233528733253479|  18400.0|
# |1974-11-06|                0.0|           3.90625|            3.84375|              3.875|  1.1786580085754397|  44000.0|
# |1974-11-06|                0.0|1.7083333730697632|              1.625|              1.625|0.003531132126227...|   9000.0|
# |1974-11-06| 1.9069914817810056|1.9069914817810056| 1.8748059272766116| 1.8748059272766116| 0.20613886415958405|3649100.0|
# |1974-11-06| 0.7407407164573669|0.7870370149612427| 0.6944444179534912| 0.6944444179534912|  0.5828065276145935|  11100.0|
# |1974-11-06| 0.6213991641998291|0.6378600597381592| 0.6131687164306641| 0.6213991641998291| 0.15668462216854095|1436400.0|
# |1974-11-06|                0.0|          1.203125|            1.15625|            1.15625| 0.08903799951076508| 224800.0|
# |1974-11-06|                0.0|            2.4375|             2.4375|             2.4375|  1.5703706741333008|    400.0|
# +----------+-------------------+------------------+-------------------+-------------------+--------------------+---------+
# only showing top 20 rows

# %%
import zipfile
# TODO: Replace with the actual path to parquet files
parquet_path = "/content/drive/MyDrive/parquet/stocks_1974.zip"

# Replace "/content/drive/MyDrive/parquet/stocks_1974.zip" with the actual path to zipped Parquet file
zipped_parquet_path = "/content/drive/MyDrive/parquet/stocks_1974.zip"
unzipped_parquet_path = "/content/drive/MyDrive/parquet/unzipped_stocks_1974"

# Create a directory to extract the contents
os.makedirs(unzipped_parquet_path, exist_ok=True)

# Unzip the Parquet file
with zipfile.ZipFile(zipped_parquet_path, 'r') as zip_ref:
    zip_ref.extractall(unzipped_parquet_path)

# List the contents of the Parquet directory
contents = os.listdir('/content/drive/MyDrive/parquet/unzipped_stocks_1974/content/stocks_1974.parquet')
print("Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_1974/content/stocks_1974.parquet:")
for item in contents:
    print(item)
# Out:
# Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_1974/content/stocks_1974.parquet:
# ._SUCCESS.crc
# _SUCCESS
# part-00000-dbd4d770-4b28-46a3-b35d-5a3311207199-c000.snappy.parquet
# part-00001-dbd4d770-4b28-46a3-b35d-5a3311207199-c000.snappy.parquet
# .part-00000-dbd4d770-4b28-46a3-b35d-5a3311207199-c000.snappy.parquet.crc
# .part-00001-dbd4d770-4b28-46a3-b35d-5a3311207199-c000.snappy.parquet.crc

# %%
# Test 1 - Null values using Deequ Verification Suite
for col_name in data_1974.columns:
    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Null check for column {col_name}") \
        .isComplete(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_1974).addCheck(check).run()

    # Display the results of the check for each column
    print(f"Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Null Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 2 - Zero values using Deequ Verification Suite
for col_name in data_1974.columns:
    # Convert column values to string for Zero check
    data_1974_str = data_1974.withColumn(col_name, F.col(col_name).cast("string"))

    # Define a Check for each column for Zero values
    zero_check = Check(spark, level=CheckLevel.Error, description=f"Zero values check for column {col_name}") \
        .isComplete(col_name)

    # Run Zero check
    zero_result = VerificationSuite(spark).onData(data_1974_str).addCheck(zero_check).run()

    # Display the results of the Zero check for each column
    print(f"Zero Values Check for Column {col_name}:")
    print(f"  - Has errors: {zero_result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in zero_result.checkResults[0]:
        print(f"  - Number of errors: {zero_result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in zero_result.checkResults[0]:
        print(f"  - Error details: {zero_result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Zero Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 3 - Negative values using Deequ Verification Suite
table_negative_values = []

for col_name in data_1974.columns:
    # Convert column values to string
    data_1974_str = data_1974.withColumn(col_name, col(col_name).cast("string"))

    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Negative check for column {col_name}") \
        .isNonNegative(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_1974_str).addCheck(check).run()

    # Display the results of the Negative check for each column
    print(f"Negative Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Negative Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Ensure the data type is correct (assuming 'double' for numeric values)
data_1974_str = data_1974.withColumn("adj_close", col("adj_close").cast("double"))

# %%
# Assuming 'double' for numeric values
data_1974_str = data_1974.withColumn("adj_close", col("adj_close").cast("double"))

# Define a Check for the adj_close column
check = Check(spark, level=CheckLevel.Error, description="Negative check for column adj_close") \
    .isNonNegative("adj_close")

# Add the check to the Verification Suite
result = VerificationSuite(spark).onData(data_1974_str).addCheck(check).run()

# Display the results of the Negative check for the adj_close column
print("Negative Values Check for Column adj_close:")
print(f"  - Has errors: {result.status == 'Error'}")

# Check if there are errors before trying to access the number of errors
if 'numRecordsFailed' in result.checkResults[0]:
    print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of errors: 0")

# Check if 'constraintMessage' is present before accessing it
if 'constraintMessage' in result.checkResults[0]:
    print(f"  - Error details: {result.checkResults[0]['constraintMessage']}")
else:
    print("  - Error details: No constraint message available")
# Out:
# Negative Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
#Test 4
# Create a Spark session
spark = SparkSession.builder.appName("MaxValuesTest").getOrCreate()

# Load data
data_path = "/content/drive/MyDrive/parquet/unzipped_stocks_1974/content/stocks_1974.parquet"
data_1974 = spark.read.parquet(data_path)

# Use Column Profiler Runner to generate summary statistics
column_profiles = ColumnProfilerRunner(spark) \
    .onData(data_1974) \
    .run()

# Extract maximum values for all numeric columns
max_values = {}

for col_name, profile in column_profiles.profiles.items():
    if profile.dataType == "Integral" or profile.dataType == "Fractional":
        max_values[col_name] = profile.maximum

# Display the maximum values
print("Maximum Values for Numeric Columns:")
for col_name, max_value in max_values.items():
    print(f"{col_name}: {max_value}")
# Out:
# Maximum Values for Numeric Columns:
# open: 367.5
# low: 364.5833435058594
# close: 367.5
# volume: 75315200.0
# adj_close: 292.9978332519531
# high: 376.6666564941406

# %%
#Test 5
# Assuming the column containing stock tickers is named 'Symbol' in metadata_df_pbd
stock_ticker_col = 'Symbol'

# Extract distinct stock tickers from the metadata
distinct_stock_tickers_metadata = metadata_df_pbd.select(col(stock_ticker_col)).distinct()

# Convert the distinct stock tickers to a list
distinct_tickers_list_metadata = [row[stock_ticker_col] for row in distinct_stock_tickers_metadata.collect()]

# Define a check to verify if stock tickers appear in the metadata
ticker_check = Check(spark, level=CheckLevel.Warning, description="Stock Ticker check") \
    .isContainedIn(stock_ticker_col, distinct_tickers_list_metadata)

# Run the check using the Verification Suite
verification_result = VerificationSuite(spark).onData(metadata_df_pbd).addCheck(ticker_check).run()

# Display the results of the stock ticker check
print("Stock Ticker Check Results:")
print(f"  - Has warnings: {verification_result.status == 'Warning'}")

# Check if there are warnings before trying to access the number of warnings
if 'numRecordsFailed' in verification_result.checkResults[0]:
    print(f"  - Number of warnings: {verification_result.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of warnings: 0")

# Check if 'constraintMessage' is present before accessing it
if 'constraintMessage' in verification_result.checkResults[0]:
    print(f"  - Warning details: {verification_result.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Warning details: No constraint message available\n")
# Out:
# Stock Ticker Check Results:
#   - Has warnings: False
#   - Number of warnings: 0
#   - Warning details: No constraint message available

# %%
#Test 6
# Specify the column to check
col_name = 'date'

# Check for uniqueness in data_1974 based on the 'date' column
unique_check_data_1974_column = Check(spark, level=CheckLevel.Error, description=f"Uniqueness check for {col_name}") \
    .isUnique(col_name)

# Investigate duplicate values in the 'date' column
data_1974.groupBy("date").count().filter("count > 1").show()

# Remove duplicate rows based on the 'date' column
data_1974 = data_1974.dropDuplicates(["date"])

# Check for general duplicates in data_1974 for the 'date' column
duplicate_check_data_1974_column = Check(spark, level=CheckLevel.Error,
                                          description=f"Duplicate check for {col_name}") \
    .hasSize(lambda x: x == data_1974.select(col_name).distinct().count(),
             f"Duplicate check for {col_name}")

# Run checks for the 'date' column using the Verification Suite
verification_result_data_1974_column = VerificationSuite(spark) \
    .onData(data_1974) \
    .addCheck(unique_check_data_1974_column) \
    .addCheck(duplicate_check_data_1974_column) \
    .run()

# Display results for the 'date' column
print(f"\nVerification Results for column {col_name} in data_1974:")
print(f"  - Has errors: {verification_result_data_1974_column.status == 'Error'}")
print(f"  - Number of uniqueness errors: {verification_result_data_1974_column.checkResults[0]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1974_column.checkResults[0] else "0")
print(f"  - Number of duplicate errors: {verification_result_data_1974_column.checkResults[1]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1974_column.checkResults[1] else "0")
print(f"  - Uniqueness error details: {verification_result_data_1974_column.checkResults[0]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1974_column.checkResults[0] else "No constraint message available")
print(f"  - Duplicate error details: {verification_result_data_1974_column.checkResults[1]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1974_column.checkResults[1] else "No constraint message available")

# Print the content of the column with errors
if verification_result_data_1974_column.status == 'Error':
    print(f"  - Content of the column with errors for {col_name}:")
    for check_result in verification_result_data_1974_column.checkResults:
        print(check_result)
# Out:
# Verification Results for column date in data_1974:
#   - Has errors: False
# 0
# 0
# No constraint message available
# No constraint message available

# %%
#Test 6
# 'Symbol' is the column representing stock tickers in metadata_df_pbd
stock_ticker_col_metadata = 'Symbol'

# Check for uniqueness in metadata_df_pbd based on 'Symbol'
unique_check_metadata = Check(spark, level=CheckLevel.Error, description="Uniqueness check for stock tickers") \
    .isUnique(stock_ticker_col_metadata)

# Check for general duplicates in metadata_df_pbd
duplicate_check_metadata = Check(spark, level=CheckLevel.Error, description="Duplicate check for entire metadata") \
    .hasSize(lambda x: x == metadata_df_pbd.count(), "Duplicate check for entire metadata")

# Run both checks using the Verification Suite
verification_result_metadata = VerificationSuite(spark) \
    .onData(metadata_df_pbd) \
    .addCheck(unique_check_metadata) \
    .addCheck(duplicate_check_metadata) \
    .run()

# Display the results of the checks for metadata_df_pbd
print("Verification Results for metadata_df_pbd:")
print(f"  - Has errors: {verification_result_metadata.status == 'Error'}")

# Check if there are errors in the uniqueness check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[0]:
    print(f"  - Number of uniqueness errors: {verification_result_metadata.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of uniqueness errors: 0")

# Check if there are errors in the duplicate check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[1]:
    print(f"  - Number of duplicate errors: {verification_result_metadata.checkResults[1]['numRecordsFailed']}")
else:
    print("  - Number of duplicate errors: 0")

# Check if 'constraintMessage' is present before accessing it for uniqueness check
if 'constraintMessage' in verification_result_metadata.checkResults[0]:
    print(f"  - Uniqueness error details: {verification_result_metadata.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Uniqueness error details: No constraint message available\n")

# Check if 'constraintMessage' is present before accessing it for duplicate check
if 'constraintMessage' in verification_result_metadata.checkResults[1]:
    print(f"  - Duplicate error details: {verification_result_metadata.checkResults[1]['constraintMessage']}\n")
else:
    print("  - Duplicate error details: No constraint message available\n")
# Out:
# Verification Results for metadata_df_pbd:
#   - Has errors: False
#   - Number of uniqueness errors: 0
#   - Number of duplicate errors: 0
#   - Uniqueness error details: No constraint message available
#
#   - Duplicate error details: No constraint message available

# %% [markdown]
# **YEAR 1985**

# %%
#TODO: Write your code here
year = 1985
# Define the data schema with string data types
data_schema = StructType([
    StructField("date", StringType(), True),
    StructField("open", StringType(), True),
    StructField("high", StringType(), True),
    StructField("low", StringType(), True),
    StructField("close", StringType(), True),
    StructField("adj_close", StringType(), True),
    StructField("volume", StringType(), True),
])

# Path to the CSV files for the year 1963
data_path_1985 = "/content/stocks/1985/*/*/*"


# Read in the data for 2018 with the specified schema
data_1985 = spark.read.csv(data_path_1985, schema=data_schema)

# Show the first few rows of the DataFrame
data_1985.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+--------------------+----------+
# |      date|              open|              high|               low|             close|           adj_close|    volume|
# +----------+------------------+------------------+------------------+------------------+--------------------+----------+
# |      Date|              Open|              High|               Low|             Close|           Adj Close|    Volume|
# |1985-12-19|11.858804702758787|12.015000343322756|  11.8347749710083|  11.8347749710083|   6.174869060516357|  856500.0|
# |1985-12-19|               0.0|12.399999618530273|12.199999809265135|12.399999618530273|  10.775887489318848|    4000.0|
# |1985-12-19| 1.203703761100769| 1.203703761100769|1.1666666269302368| 1.203703761100769|-1.50225855009007...|  665500.0|
# |1985-12-19|0.3973214328289032|           0.40625|0.3950892984867096|0.4017857015132904|  0.3183508515357971|67530400.0|
# |1985-12-19|           71250.0|           72500.0|           68750.0|           72500.0|         66465.96875|       0.0|
# |1985-12-19| 2.450000047683716|2.4749999046325684| 2.424999952316284| 2.424999952316284| 0.10218074172735214|   78400.0|
# |1985-12-19|1.8447020053863523| 1.879772424697876|1.8447020053863523|1.8657442331314087| 0.03954273834824562|17471800.0|
# |1985-12-19|             11.25|             11.25|            11.125|            11.125|  6.8110761642456055|    3900.0|
# |1985-12-19|           3.28125|            3.3125|           3.28125|           3.28125|  2.2279210090637207|   93600.0|
# |1985-12-19|3.5291554927825928|3.5800566673278813|  3.51218843460083|3.5800566673278813|  2.0052380561828613| 4080400.0|
# |1985-12-19| 2.924423933029175|2.9492070674896236|2.8996405601501465| 2.930619716644287|  1.6502289772033691| 2469300.0|
# |1985-12-19|           0.96875|0.9895833134651184|           0.96875|           0.96875|    0.84611576795578|  352800.0|
# |1985-12-19|12.833333015441895|12.916666984558105|12.666666984558105|12.666666984558105|  0.9736819267272948|   16800.0|
# |1985-12-19|               5.0|              5.25|               5.0|               5.0|  3.1628589630126958|    1800.0|
# |1985-12-19|1.7848557233810425| 1.790865421295166|1.7848557233810425|1.7848557233810425|0.000479861890198...|  773700.0|
# |1985-12-19|               0.0|            10.375|             9.875|            10.125|              10.125|    8400.0|
# |1985-12-19|            15.125|             15.25|            15.125|            15.125|  10.485779762268066|   15900.0|
# |1985-12-19|              24.0|            24.125|            23.625|            23.875|  3.2953152656555176|  520600.0|
# |1985-12-19|            17.125|            17.125| 16.91666603088379| 16.91666603088379|   4.069779396057129|  125700.0|
# +----------+------------------+------------------+------------------+------------------+--------------------+----------+
# only showing top 20 rows

# %%
import zipfile
# TODO: Replace with the actual path to parquet files
parquet_path = "/content/drive/MyDrive/parquet/stocks_1985.zip"

# Replace "/content/drive/MyDrive/parquet/stocks_1985.zip" with the actual path to zipped Parquet file
zipped_parquet_path = "/content/drive/MyDrive/parquet/stocks_1985.zip"
unzipped_parquet_path = "/content/drive/MyDrive/parquet/unzipped_stocks_1985"

# Create a directory to extract the contents
os.makedirs(unzipped_parquet_path, exist_ok=True)

# Unzip the Parquet file
with zipfile.ZipFile(zipped_parquet_path, 'r') as zip_ref:
    zip_ref.extractall(unzipped_parquet_path)

# List the contents of the Parquet directory
contents = os.listdir('/content/drive/MyDrive/parquet/unzipped_stocks_1985/content/stocks_1985.parquet')
print("Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_1985/content/stocks_1985.parquet:")
for item in contents:
    print(item)
# Out:
# Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_1985/content/stocks_1985.parquet:
# part-00001-2ee97d16-b78c-4a20-b45f-ce48fa9d8f79-c000.snappy.parquet
# .part-00000-2ee97d16-b78c-4a20-b45f-ce48fa9d8f79-c000.snappy.parquet.crc
# ._SUCCESS.crc
# _SUCCESS
# .part-00001-2ee97d16-b78c-4a20-b45f-ce48fa9d8f79-c000.snappy.parquet.crc
# part-00000-2ee97d16-b78c-4a20-b45f-ce48fa9d8f79-c000.snappy.parquet

# %%
# Test 1 - Null values using Deequ Verification Suite
for col_name in data_1985.columns:
    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Null check for column {col_name}") \
        .isComplete(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_1985).addCheck(check).run()

    # Display the results of the check for each column
    print(f"Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Null Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column open:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column high:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column low:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column volume:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Drop rows with null values in specific columns
columns_with_nulls = ['open', 'high', 'low', 'close', 'adj_close', 'volume']
data_1985_cleaned = data_1985.dropna(subset=columns_with_nulls)

# Display the count of null values after cleaning
for col_name in columns_with_nulls:
    null_count_after_cleaning = data_1985_cleaned.where(col(col_name).isNull()).count()
    print(f"After cleaning, Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {null_count_after_cleaning > 0}")
    print(f"  - Number of errors: {null_count_after_cleaning}")
    print("  - Error details: No constraint message available\n")
# Out:
# After cleaning, Null Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 2 - Zero values using Deequ Verification Suite
for col_name in data_1985.columns:
    # Convert column values to string for Zero check
    data_1985_str = data_1985.withColumn(col_name, F.col(col_name).cast("string"))

    # Define a Check for each column for Zero values
    zero_check = Check(spark, level=CheckLevel.Error, description=f"Zero values check for column {col_name}") \
        .isComplete(col_name)

    # Run Zero check
    zero_result = VerificationSuite(spark).onData(data_1985_str).addCheck(zero_check).run()

    # Display the results of the Zero check for each column
    print(f"Zero Values Check for Column {col_name}:")
    print(f"  - Has errors: {zero_result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in zero_result.checkResults[0]:
        print(f"  - Number of errors: {zero_result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in zero_result.checkResults[0]:
        print(f"  - Error details: {zero_result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Zero Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column open:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column high:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column low:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column volume:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
from pyspark.sql.functions import col

# Assuming 'data_1985' is your DataFrame

# Drop rows with zero values in specific columns
columns_with_zeros = ['open', 'high', 'low', 'close', 'adj_close', 'volume']
for col_name in columns_with_zeros:
    data_1985 = data_1985.filter(col(col_name) != 0)

# Display the count of zero values after cleaning
for col_name in columns_with_zeros:
    zero_count_after_cleaning = data_1985.where(col(col_name) == 0).count()
    print(f"After cleaning, Zero Values Check for Column {col_name}:")
    print(f"  - Has errors: {zero_count_after_cleaning > 0}")
    print(f"  - Number of errors: {zero_count_after_cleaning}")
    print("  - Error details: No constraint message available\n")
# Out:
# After cleaning, Zero Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 3 - Negative values using Deequ Verification Suite
table_negative_values = []

for col_name in data_1985.columns:
    # Convert column values to string
    data_1985_str = data_1985.withColumn(col_name, col(col_name).cast("string"))

    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Negative check for column {col_name}") \
        .isNonNegative(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_1985_str).addCheck(check).run()

    # Display the results of the Negative check for each column
    print(f"Negative Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Negative Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
from pyspark.sql.functions import col

# Drop rows with negative values in specific columns
columns_with_negatives = ['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume']
for col_name in columns_with_negatives:
    data_1985 = data_1985.filter(col(col_name) >= 0)

# Display the count of negative values after cleaning
for col_name in columns_with_negatives:
    negative_count_after_cleaning = data_1985.where(col(col_name) < 0).count()
    print(f"After cleaning, Negative Values Check for Column {col_name}:")
    print(f"  - Has errors: {negative_count_after_cleaning > 0}")
    print(f"  - Number of errors: {negative_count_after_cleaning}")
    print("  - Error details: No constraint message available\n")
# Out:
# After cleaning, Negative Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Negative Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Negative Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Negative Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Negative Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Negative Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Negative Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
#Test 4
# Create a Spark session
spark = SparkSession.builder.appName("MaxValuesTest").getOrCreate()

# Load data
data_path = "/content/drive/MyDrive/parquet/unzipped_stocks_1985/content/stocks_1985.parquet"
data_1985 = spark.read.parquet(data_path)

# Use Column Profiler Runner to generate summary statistics
column_profiles = ColumnProfilerRunner(spark) \
    .onData(data_1985) \
    .run()

# Extract maximum values for all numeric columns
max_values = {}

for col_name, profile in column_profiles.profiles.items():
    if profile.dataType == "Integral" or profile.dataType == "Fractional":
        max_values[col_name] = profile.maximum

# Display the maximum values
print("Maximum Values for Numeric Columns:")
for col_name, max_value in max_values.items():
    print(f"{col_name}: {max_value}")
# Out:
# Maximum Values for Numeric Columns:
# open: 100000.0
# low: 219375.0
# close: 221250.0
# volume: 183495200.0
# adj_close: 190826.34375
# high: 224062.5

# %%
from pydeequ.profiles import ColumnProfilerRunner
#Test 4
# Use Column Profiler Runner to generate summary statistics for metadata_df_pbd
metadata_column_profiles = ColumnProfilerRunner(spark) \
    .onData(metadata_df_pbd) \
    .run()

# Extract maximum values for all numeric columns in metadata_df_pbd
metadata_max_values = {}

for col_name, profile in metadata_column_profiles.profiles.items():
    if profile.dataType == "Integral" or profile.dataType == "Fractional":
        metadata_max_values[col_name] = profile.maximum

# Display the maximum values for metadata_df_pbd
print("Maximum Values for Numeric Columns in metadata_df_pbd:")
for col_name, max_value in metadata_max_values.items():
    print(f"{col_name}: {max_value}")
# Out:
# Maximum Values for Numeric Columns in metadata_df_pbd:
# Round Lot Size: 100.0

# %%
#Test 5
# Assuming the column containing stock tickers is named 'Symbol' in metadata_df_pbd
stock_ticker_col = 'Symbol'

# Extract distinct stock tickers from the metadata
distinct_stock_tickers_metadata = metadata_df_pbd.select(col(stock_ticker_col)).distinct()

# Convert the distinct stock tickers to a list
distinct_tickers_list_metadata = [row[stock_ticker_col] for row in distinct_stock_tickers_metadata.collect()]

# Define a check to verify if stock tickers appear in the metadata
ticker_check = Check(spark, level=CheckLevel.Warning, description="Stock Ticker check") \
    .isContainedIn(stock_ticker_col, distinct_tickers_list_metadata)

# Run the check using the Verification Suite
verification_result = VerificationSuite(spark).onData(metadata_df_pbd).addCheck(ticker_check).run()

# Display the results of the stock ticker check
print("Stock Ticker Check Results:")
print(f"  - Has warnings: {verification_result.status == 'Warning'}")

# Check if there are warnings before trying to access the number of warnings
if 'numRecordsFailed' in verification_result.checkResults[0]:
    print(f"  - Number of warnings: {verification_result.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of warnings: 0")

# Check if 'constraintMessage' is present before accessing it
if 'constraintMessage' in verification_result.checkResults[0]:
    print(f"  - Warning details: {verification_result.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Warning details: No constraint message available\n")
# Out:
# Stock Ticker Check Results:
#   - Has warnings: False
#   - Number of warnings: 0
#   - Warning details: No constraint message available

# %%
#Test 6
# Specify the column to check
col_name = 'date'

# Check for uniqueness in data_1985 based on the 'date' column
unique_check_data_1985_column = Check(spark, level=CheckLevel.Warning, description=f"Uniqueness check for {col_name}") \
    .isUnique(col_name)

# Check for general duplicates in data_1985 for the 'date' column
duplicate_check_data_1985_column = Check(spark, level=CheckLevel.Warning,
                                          description=f"Duplicate check for {col_name}") \
    .hasSize(lambda x: x == data_1985.select(col_name).count(),
             f"Duplicate check for {col_name}")

# Run checks for the 'date' column using the Verification Suite
verification_result_data_1985_column = VerificationSuite(spark) \
    .onData(data_1985) \
    .addCheck(unique_check_data_1985_column) \
    .addCheck(duplicate_check_data_1985_column) \
    .run()

# Display results for the 'date' column
print(f"\nVerification Results for column {col_name} in data_1985:")
print(f"  - Has errors: {verification_result_data_1985_column.status == 'Error'}")
print(f"  - Number of uniqueness errors: {verification_result_data_1985_column.checkResults[0]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1985_column.checkResults[0] else "0")
print(f"  - Number of duplicate errors: {verification_result_data_1985_column.checkResults[1]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1985_column.checkResults[1] else "0")
print(f"  - Uniqueness error details: {verification_result_data_1985_column.checkResults[0]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1985_column.checkResults[0] else "No constraint message available")
print(f"  - Duplicate error details: {verification_result_data_1985_column.checkResults[1]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1985_column.checkResults[1] else "No constraint message available")

# Print the content of the column with errors
if verification_result_data_1985_column.status == 'Error':
    print(f"  - Content of the column with errors for {col_name}:")
    for check_result in verification_result_data_1985_column.checkResults:
        print(check_result)
# Out:
# Verification Results for column date in data_1985:
#   - Has errors: False
# 0
# 0
# No constraint message available
# No constraint message available

# %%
#Test 6
# 'Symbol' is the column representing stock tickers in metadata_df_pbd
stock_ticker_col_metadata = 'Symbol'

# Check for uniqueness in metadata_df_pbd based on 'Symbol'
unique_check_metadata = Check(spark, level=CheckLevel.Error, description="Uniqueness check for stock tickers") \
    .isUnique(stock_ticker_col_metadata)

# Check for general duplicates in metadata_df_pbd
duplicate_check_metadata = Check(spark, level=CheckLevel.Error, description="Duplicate check for entire metadata") \
    .hasSize(lambda x: x == metadata_df_pbd.count(), "Duplicate check for entire metadata")

# Run both checks using the Verification Suite
verification_result_metadata = VerificationSuite(spark) \
    .onData(metadata_df_pbd) \
    .addCheck(unique_check_metadata) \
    .addCheck(duplicate_check_metadata) \
    .run()

# Display the results of the checks for metadata_df_pbd
print("Verification Results for metadata_df_pbd:")
print(f"  - Has errors: {verification_result_metadata.status == 'Error'}")

# Check if there are errors in the uniqueness check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[0]:
    print(f"  - Number of uniqueness errors: {verification_result_metadata.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of uniqueness errors: 0")

# Check if there are errors in the duplicate check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[1]:
    print(f"  - Number of duplicate errors: {verification_result_metadata.checkResults[1]['numRecordsFailed']}")
else:
    print("  - Number of duplicate errors: 0")

# Check if 'constraintMessage' is present before accessing it for uniqueness check
if 'constraintMessage' in verification_result_metadata.checkResults[0]:
    print(f"  - Uniqueness error details: {verification_result_metadata.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Uniqueness error details: No constraint message available\n")

# Check if 'constraintMessage' is present before accessing it for duplicate check
if 'constraintMessage' in verification_result_metadata.checkResults[1]:
    print(f"  - Duplicate error details: {verification_result_metadata.checkResults[1]['constraintMessage']}\n")
else:
    print("  - Duplicate error details: No constraint message available\n")
# Out:
# Verification Results for metadata_df_pbd:
#   - Has errors: False
#   - Number of uniqueness errors: 0
#   - Number of duplicate errors: 0
#   - Uniqueness error details: No constraint message available
#
#   - Duplicate error details: No constraint message available

# %% [markdown]
# **YEAR 1996**

# %%
#TODO: Write your code here
year = 1996
# Define the data schema with string data types
data_schema = StructType([
    StructField("date", StringType(), True),
    StructField("open", StringType(), True),
    StructField("high", StringType(), True),
    StructField("low", StringType(), True),
    StructField("close", StringType(), True),
    StructField("adj_close", StringType(), True),
    StructField("volume", StringType(), True),
])

# Path to the CSV files for the year 1996
data_path_1996 = "/content/stocks/1996/*/*/*"


# Read in the data for 1996 with the specified schema
data_1996 = spark.read.csv(data_path_1996, schema=data_schema)

# Show the first few rows of the DataFrame
data_1996.show()
# Out:
# +----------+------------------+-------------------+------------------+------------------+------------------+----------+
# |      date|              open|               high|               low|             close|         adj_close|    volume|
# +----------+------------------+-------------------+------------------+------------------+------------------+----------+
# |      Date|              Open|               High|               Low|             Close|         Adj Close|    Volume|
# |1996-12-31|  37.9433708190918|   38.1356086730957| 37.53485870361328|  38.1356086730957|  27.1257438659668| 1025800.0|
# |1996-12-31|              3.25|               3.25|            3.0625|            3.0625|2.8300909996032715|   17200.0|
# |1996-12-31| 3.851851940155029|  4.148148059844972| 3.851851940155029| 4.148148059844972|-147.2616424560547|    1300.0|
# |1996-12-31|0.4170095920562744|0.43895748257637024|0.4170095920562744|0.4279835522174835|0.3635455369949341|  269200.0|
# |1996-12-31|0.7633928656578064| 0.7678571343421936|0.7410714030265808|0.7455357313156128|0.6471554040908813|95936400.0|
# |1996-12-31|            13.375|             13.375|             13.25|           13.3125| 2.401604175567627|   38000.0|
# |1996-12-31|          5.609375|            6.03125|          5.609375|           6.03125| 4.643967151641847|  314400.0|
# |1996-12-31| 9.118518829345703|  9.186062812805176| 9.118518829345703| 9.118518829345703|5.7967143058776855|    9700.0|
# |1996-12-31|            3750.0|            4218.75|            3750.0|            3750.0| 3437.894775390625|       0.0|
# |1996-12-31|            8.9375|               9.25|            8.9375|              9.25| 4.859931468963623|   51400.0|
# |1996-12-31|            5.9375|             6.4375|            5.9375|            6.0625|            6.0625|   19400.0|
# |1996-12-31|11.671422958374025| 11.727535247802734|11.390859603881836|11.390859603881836| 4.043461322784424| 3680900.0|
# |1996-12-31|             2.125| 2.2083332538604736|             2.125|2.1527776718139653|2.1527776718139653|  641700.0|
# |1996-12-31|              19.5|               22.5|              19.5|              19.5|              19.5|    1600.0|
# |1996-12-31|           61380.0|            61627.5|           58410.0|           58905.0|           58905.0|       0.0|
# |1996-12-31|10.916666984558104| 11.083333015441896|10.833333015441896|11.083333015441896|11.083333015441896|   76500.0|
# |1996-12-31|14.512471199035645| 14.512471199035645|14.512471199035645|14.512471199035645| 5.268472194671631|     800.0|
# |1996-12-31|             5.125|                5.5|             5.125|               5.5| 4.065547466278076|    3100.0|
# |1996-12-31|            4.6875|             4.8125|           4.59375|          4.671875| 4.581388473510742| 6066400.0|
# +----------+------------------+-------------------+------------------+------------------+------------------+----------+
# only showing top 20 rows

# %%
import zipfile
# TODO: Replace with the actual path to parquet files
parquet_path = "/content/drive/MyDrive/parquet/stocks_1996.zip"

# Replace "/content/drive/MyDrive/parquet/stocks_1996.zip" with the actual path to zipped Parquet file
zipped_parquet_path = "/content/drive/MyDrive/parquet/stocks_1996.zip"
unzipped_parquet_path = "/content/drive/MyDrive/parquet/unzipped_stocks_1996"

# Create a directory to extract the contents
os.makedirs(unzipped_parquet_path, exist_ok=True)

# Unzip the Parquet file
with zipfile.ZipFile(zipped_parquet_path, 'r') as zip_ref:
    zip_ref.extractall(unzipped_parquet_path)

# List the contents of the Parquet directory
contents = os.listdir('/content/drive/MyDrive/parquet/unzipped_stocks_1996/content/stocks_1996.parquet')
print("Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_1996/content/stocks_1996.parquet:")
for item in contents:
    print(item)
# Out:
# Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_1996/content/stocks_1996.parquet:
# part-00001-7de0d854-0cf6-4b1c-bbc1-d30426a01d28-c000.snappy.parquet
# ._SUCCESS.crc
# _SUCCESS
# part-00000-7de0d854-0cf6-4b1c-bbc1-d30426a01d28-c000.snappy.parquet
# .part-00001-7de0d854-0cf6-4b1c-bbc1-d30426a01d28-c000.snappy.parquet.crc
# .part-00000-7de0d854-0cf6-4b1c-bbc1-d30426a01d28-c000.snappy.parquet.crc

# %%
# Test 1 - Null values using Deequ Verification Suite
# Iterate over columns and perform null check
for col_name in data_1996.columns:
    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Null check for column {col_name}") \
        .isComplete(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_1996).addCheck(check).run()

    # Display the results of the null check for each column
    print(f"Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Null Values Check for Column date:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column open:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column high:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column low:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column volume:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
from pyspark.sql.functions import col

for col_name in data_1996.columns:
    # Check if the column has null values
    null_count = data_1996.filter(col(col_name).isNull()).count()
    print(f"Null count for Column {col_name}: {null_count}")
# Out:
# Null count for Column date: 0
# Null count for Column open: 19
# Null count for Column high: 19
# Null count for Column low: 19
# Null count for Column close: 19
# Null count for Column adj_close: 19
# Null count for Column volume: 19

# %%
from pyspark.sql.functions import col

# Drop rows with null values in specific columns
columns_with_nulls = ['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume']
for col_name in columns_with_nulls:
    data_1996 = data_1996.filter(col(col_name).isNotNull())

# Display the count of null values after cleaning
for col_name in columns_with_nulls:
    null_count_after_cleaning = data_1996.where(col(col_name).isNull()).count()
    print(f"After cleaning, Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {null_count_after_cleaning > 0}")
    print(f"  - Number of errors: {null_count_after_cleaning}")
    print("  - Error details: No constraint message available\n")
# Out:
# After cleaning, Null Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 2 - Zero values using Deequ Verification Suite
for col_name in data_1996.columns:
    # Convert column values to string for Zero check
    data_1996_str = data_1996.withColumn(col_name, F.col(col_name).cast("string"))

    # Define a Check for each column for Zero values
    zero_check = Check(spark, level=CheckLevel.Error, description=f"Zero values check for column {col_name}") \
        .isComplete(col_name)

    # Run Zero check
    zero_result = VerificationSuite(spark).onData(data_1996_str).addCheck(zero_check).run()

    # Display the results of the Zero check for each column
    print(f"Zero Values Check for Column {col_name}:")
    print(f"  - Has errors: {zero_result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in zero_result.checkResults[0]:
        print(f"  - Number of errors: {zero_result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in zero_result.checkResults[0]:
        print(f"  - Error details: {zero_result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Zero Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 3 - Negative values using Deequ Verification Suite
table_negative_values = []

for col_name in data_1996.columns:
    # Convert column values to string
    data_1996_str = data_1996.withColumn(col_name, col(col_name).cast("string"))

    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Negative check for column {col_name}") \
        .isNonNegative(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_1996_str).addCheck(check).run()

    # Display the results of the Negative check for each column
    print(f"Negative Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Negative Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
#Test 4
# Create a Spark session
spark = SparkSession.builder.appName("MaxValuesTest").getOrCreate()

# Load data
data_path = "/content/drive/MyDrive/parquet/unzipped_stocks_1996/content/stocks_1996.parquet"
data_1996 = spark.read.parquet(data_path)

# Use Column Profiler Runner to generate summary statistics
column_profiles = ColumnProfilerRunner(spark) \
    .onData(data_1996) \
    .run()

# Extract maximum values for all numeric columns
max_values = {}

for col_name, profile in column_profiles.profiles.items():
    if profile.dataType == "Integral" or profile.dataType == "Fractional":
        max_values[col_name] = profile.maximum

# Display the maximum values
print("Maximum Values for Numeric Columns:")
for col_name, max_value in max_values.items():
    print(f"{col_name}: {max_value}")
# Out:
# Maximum Values for Numeric Columns:
# open: 498750.0
# low: 490000.0
# close: 507500.0
# volume: 546630400.0
# adj_close: 507500.0
# high: 507500.0

# %%
from pydeequ.profiles import ColumnProfilerRunner
#Test 4
# Use Column Profiler Runner to generate summary statistics for metadata_df_pbd
metadata_column_profiles = ColumnProfilerRunner(spark) \
    .onData(metadata_df_pbd) \
    .run()

# Extract maximum values for all numeric columns in metadata_df_pbd
metadata_max_values = {}

for col_name, profile in metadata_column_profiles.profiles.items():
    if profile.dataType == "Integral" or profile.dataType == "Fractional":
        metadata_max_values[col_name] = profile.maximum

# Display the maximum values for metadata_df_pbd
print("Maximum Values for Numeric Columns in metadata_df_pbd:")
for col_name, max_value in metadata_max_values.items():
    print(f"{col_name}: {max_value}")
# Out:
# Maximum Values for Numeric Columns in metadata_df_pbd:
# Round Lot Size: 100.0

# %%
#Test 5
# Assuming the column containing stock tickers is named 'Symbol' in metadata_df_pbd
stock_ticker_col = 'Symbol'

# Extract distinct stock tickers from the metadata
distinct_stock_tickers_metadata = metadata_df_pbd.select(col(stock_ticker_col)).distinct()

# Convert the distinct stock tickers to a list
distinct_tickers_list_metadata = [row[stock_ticker_col] for row in distinct_stock_tickers_metadata.collect()]

# Define a check to verify if stock tickers appear in the metadata
ticker_check = Check(spark, level=CheckLevel.Warning, description="Stock Ticker check") \
    .isContainedIn(stock_ticker_col, distinct_tickers_list_metadata)

# Run the check using the Verification Suite
verification_result = VerificationSuite(spark).onData(metadata_df_pbd).addCheck(ticker_check).run()

# Display the results of the stock ticker check
print("Stock Ticker Check Results:")
print(f"  - Has warnings: {verification_result.status == 'Warning'}")

# Check if there are warnings before trying to access the number of warnings
if 'numRecordsFailed' in verification_result.checkResults[0]:
    print(f"  - Number of warnings: {verification_result.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of warnings: 0")

# Check if 'constraintMessage' is present before accessing it
if 'constraintMessage' in verification_result.checkResults[0]:
    print(f"  - Warning details: {verification_result.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Warning details: No constraint message available\n")
# Out:
# Stock Ticker Check Results:
#   - Has warnings: False
#   - Number of warnings: 0
#   - Warning details: No constraint message available

# %%
#Test 6
# Specify the column to check
col_name = 'date'

# Check for uniqueness in data_1996 based on the 'date' column
unique_check_data_1996_column = Check(spark, level=CheckLevel.Warning, description=f"Uniqueness check for {col_name}") \
    .isUnique(col_name)

# Check for general duplicates in data_1996 for the 'date' column
duplicate_check_data_1996_column = Check(spark, level=CheckLevel.Warning,
                                          description=f"Duplicate check for {col_name}") \
    .hasSize(lambda x: x == data_1996.select(col_name).count(),
             f"Duplicate check for {col_name}")

# Run checks for the 'date' column using the Verification Suite
verification_result_data_1996_column = VerificationSuite(spark) \
    .onData(data_1996) \
    .addCheck(unique_check_data_1996_column) \
    .addCheck(duplicate_check_data_1996_column) \
    .run()

# Display results for the 'date' column
print(f"\nVerification Results for column {col_name} in data_1996:")
print(f"  - Has errors: {verification_result_data_1996_column.status == 'Error'}")
print(f"  - Number of uniqueness errors: {verification_result_data_1996_column.checkResults[0]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1996_column.checkResults[0] else "0")
print(f"  - Number of duplicate errors: {verification_result_data_1996_column.checkResults[1]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_1996_column.checkResults[1] else "0")
print(f"  - Uniqueness error details: {verification_result_data_1996_column.checkResults[0]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1996_column.checkResults[0] else "No constraint message available")
print(f"  - Duplicate error details: {verification_result_data_1996_column.checkResults[1]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_1996_column.checkResults[1] else "No constraint message available")

# Print the content of the column with errors
if verification_result_data_1996_column.status == 'Error':
    print(f"  - Content of the column with errors for {col_name}:")
    for check_result in verification_result_data_1996_column.checkResults:
        print(check_result)
# Out:
# Verification Results for column date in data_1996:
#   - Has errors: False
# 0
# 0
# No constraint message available
# No constraint message available

# %%
#Test 6
# 'Symbol' is the column representing stock tickers in metadata_df_pbd
stock_ticker_col_metadata = 'Symbol'

# Check for uniqueness in metadata_df_pbd based on 'Symbol'
unique_check_metadata = Check(spark, level=CheckLevel.Error, description="Uniqueness check for stock tickers") \
    .isUnique(stock_ticker_col_metadata)

# Check for general duplicates in metadata_df_pbd
duplicate_check_metadata = Check(spark, level=CheckLevel.Error, description="Duplicate check for entire metadata") \
    .hasSize(lambda x: x == metadata_df_pbd.count(), "Duplicate check for entire metadata")

# Run both checks using the Verification Suite
verification_result_metadata = VerificationSuite(spark) \
    .onData(metadata_df_pbd) \
    .addCheck(unique_check_metadata) \
    .addCheck(duplicate_check_metadata) \
    .run()

# Display the results of the checks for metadata_df_pbd
print("Verification Results for metadata_df_pbd:")
print(f"  - Has errors: {verification_result_metadata.status == 'Error'}")

# Check if there are errors in the uniqueness check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[0]:
    print(f"  - Number of uniqueness errors: {verification_result_metadata.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of uniqueness errors: 0")

# Check if there are errors in the duplicate check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[1]:
    print(f"  - Number of duplicate errors: {verification_result_metadata.checkResults[1]['numRecordsFailed']}")
else:
    print("  - Number of duplicate errors: 0")

# Check if 'constraintMessage' is present before accessing it for uniqueness check
if 'constraintMessage' in verification_result_metadata.checkResults[0]:
    print(f"  - Uniqueness error details: {verification_result_metadata.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Uniqueness error details: No constraint message available\n")

# Check if 'constraintMessage' is present before accessing it for duplicate check
if 'constraintMessage' in verification_result_metadata.checkResults[1]:
    print(f"  - Duplicate error details: {verification_result_metadata.checkResults[1]['constraintMessage']}\n")
else:
    print("  - Duplicate error details: No constraint message available\n")
# Out:
# Verification Results for metadata_df_pbd:
#   - Has errors: False
#   - Number of uniqueness errors: 0
#   - Number of duplicate errors: 0
#   - Uniqueness error details: No constraint message available
#
#   - Duplicate error details: No constraint message available

# %% [markdown]
# **YEAR 2007**

# %%
#TODO: Write your code here
year = 2007
# Define the data schema with string data types
data_schema = StructType([
    StructField("date", StringType(), True),
    StructField("open", StringType(), True),
    StructField("high", StringType(), True),
    StructField("low", StringType(), True),
    StructField("close", StringType(), True),
    StructField("adj_close", StringType(), True),
    StructField("volume", StringType(), True),
])

# Path to the CSV files for the year 2007
data_path_2007 = "/content/stocks/2007/*/*/*"


# Read in the data for 2007 with the specified schema
data_2007 = spark.read.csv(data_path_2007, schema=data_schema)

# Show the first few rows of the DataFrame
data_2007.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+------------------+-----------+
# |      date|              open|              high|               low|             close|         adj_close|     volume|
# +----------+------------------+------------------+------------------+------------------+------------------+-----------+
# |      Date|              Open|              High|               Low|             Close|         Adj Close|     Volume|
# |2007-12-27| 26.67382049560547| 26.84549331665039|26.566524505615234|26.566524505615234| 24.24957847595215|  2628500.0|
# |2007-12-27| 89.70398712158203| 89.77607727050781| 88.83891296386719| 88.88697052001953| 77.58712005615234|  2743600.0|
# |2007-12-27| 15.43000030517578|15.619999885559082|15.079999923706055| 15.18000030517578|14.310813903808596|  1473200.0|
# |2007-12-27|1.3799999952316284|               1.5|1.3799999952316284|1.4800000190734863| 1.367684841156006|    16200.0|
# |2007-12-27|11.600000381469727|11.633333206176758|11.526666641235352|11.526666641235352|11.070908546447754|     1900.0|
# |2007-12-27|6.2459259033203125|6.3140740394592285|  5.96148157119751| 5.997036933898926|5.2552223205566415|   216600.0|
# |2007-12-27| 38.41999816894531| 38.77999877929688| 38.13999938964844|             38.25| 36.75344848632813|   598800.0|
# |2007-12-27|28.421428680419922| 28.99428558349609|28.257143020629886|28.367143630981445|24.623838424682614|198881900.0|
# |2007-12-27|               2.5| 2.549999952316284|2.4600000381469727|2.4800000190734863|2.4800000190734863|    34700.0|
# |2007-12-27| 55.43000030517578| 55.43999862670898| 53.77999877929688| 53.77999877929688| 53.77999877929688|    85000.0|
# |2007-12-27|15.170000076293945|15.300000190734865|14.859999656677244|14.859999656677244|14.859999656677244|   636600.0|
# |2007-12-27|  79.5999984741211|  79.7300033569336| 77.97000122070312| 78.11000061035156|  30.8148193359375|   142200.0|
# |2007-12-27| 28.56999969482422| 29.09000015258789|              28.5| 28.79999923706055| 18.81489562988281|  4849900.0|
# |2007-12-27| 22.67499923706055| 22.88500022888184| 22.59000015258789|22.729999542236328|18.812719345092773|  1658000.0|
# |2007-12-27| 17.77016830444336| 17.77016830444336| 16.38901710510254|16.427923202514652|14.784321784973145|    61100.0|
# |2007-12-27|             165.0|             165.0|             125.0|             165.0|             165.0|      200.0|
# |2007-12-27|2.7716000080108643| 2.799599885940552|2.7523999214172363|2.7708001136779785|0.3066600859165192|    77500.0|
# |2007-12-27|15.510000228881836|15.600000381469727|15.039999961853027|15.039999961853027|14.358692169189453|   133400.0|
# |2007-12-27|    29635.19921875|   29937.599609375|   28425.599609375|   29030.400390625|   29030.400390625|        0.0|
# +----------+------------------+------------------+------------------+------------------+------------------+-----------+
# only showing top 20 rows

# %%
import zipfile
# TODO: Replace with the actual path to parquet files
parquet_path = "/content/drive/MyDrive/parquet/stocks_2007.zip"

# Replace "/content/drive/MyDrive/parquet/stocks_2007.zip" with the actual path to zipped Parquet file
zipped_parquet_path = "/content/drive/MyDrive/parquet/stocks_2007.zip"
unzipped_parquet_path = "/content/drive/MyDrive/parquet/unzipped_stocks_2007"

# Create a directory to extract the contents
os.makedirs(unzipped_parquet_path, exist_ok=True)

# Unzip the Parquet file
with zipfile.ZipFile(zipped_parquet_path, 'r') as zip_ref:
    zip_ref.extractall(unzipped_parquet_path)

# List the contents of the Parquet directory
contents = os.listdir('/content/drive/MyDrive/parquet/unzipped_stocks_2007/content/stocks_2007.parquet')
print("Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_2007/content/stocks_2007.parquet:")
for item in contents:
    print(item)
# Out:
# Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_2007/content/stocks_2007.parquet:
# part-00001-f35f7986-9310-44ce-a8ef-031749839bbb-c000.snappy.parquet
# ._SUCCESS.crc
# _SUCCESS
# .part-00000-f35f7986-9310-44ce-a8ef-031749839bbb-c000.snappy.parquet.crc
# part-00000-f35f7986-9310-44ce-a8ef-031749839bbb-c000.snappy.parquet
# .part-00001-f35f7986-9310-44ce-a8ef-031749839bbb-c000.snappy.parquet.crc

# %%
# Test 1 - Null values using Deequ Verification Suite
# Iterate over columns and perform null check
for col_name in data_2007.columns:
    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Null check for column {col_name}") \
        .isComplete(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_2007).addCheck(check).run()

    # Display the results of the null check for each column
    print(f"Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Null Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column open:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column high:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column low:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column volume:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
from pyspark.sql.functions import col

# Drop rows with null values in specific columns
columns_with_nulls = ['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume']
for col_name in columns_with_nulls:
    data_1996 = data_1996.filter(col(col_name).isNotNull())

# Display the count of null values after cleaning
for col_name in columns_with_nulls:
    null_count_after_cleaning = data_1996.where(col(col_name).isNull()).count()
    print(f"After cleaning, Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {null_count_after_cleaning > 0}")
    print(f"  - Number of errors: {null_count_after_cleaning}")
    print("  - Error details: No constraint message available\n")
# Out:
# After cleaning, Null Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 2 - Zero values using Deequ Verification Suite
for col_name in data_2007.columns:
    # Convert column values to string for Zero check
    data_2007_str = data_2007.withColumn(col_name, F.col(col_name).cast("string"))

    # Define a Check for each column for Zero values
    zero_check = Check(spark, level=CheckLevel.Error, description=f"Zero values check for column {col_name}") \
        .isComplete(col_name)

    # Run Zero check
    zero_result = VerificationSuite(spark).onData(data_2007_str).addCheck(zero_check).run()

    # Display the results of the Zero check for each column
    print(f"Zero Values Check for Column {col_name}:")
    print(f"  - Has errors: {zero_result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in zero_result.checkResults[0]:
        print(f"  - Number of errors: {zero_result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in zero_result.checkResults[0]:
        print(f"  - Error details: {zero_result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Zero Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column open:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column high:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column low:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column volume:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
from pyspark.sql.functions import col

# Drop rows with zero values in specific columns
columns_with_zeros = ['open', 'high', 'low', 'close', 'adj_close', 'volume']
for col_name in columns_with_zeros:
    data_2007 = data_2007.filter(col(col_name) != 0)

# Display the count of zero values after cleaning
for col_name in columns_with_zeros:
    zero_count_after_cleaning = data_2007.where(col(col_name) == 0).count()
    print(f"After cleaning, Zero Values Check for Column {col_name}:")
    print(f"  - Has errors: {zero_count_after_cleaning > 0}")
    print(f"  - Number of errors: {zero_count_after_cleaning}")
    print("  - Error details: No constraint message available\n")
# Out:
# After cleaning, Zero Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 3 - Negative values using Deequ Verification Suite
table_negative_values = []

for col_name in data_2007.columns:
    # Convert column values to string
    data_2007_str = data_2007.withColumn(col_name, col(col_name).cast("string"))

    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Negative check for column {col_name}") \
        .isNonNegative(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_2007_str).addCheck(check).run()

    # Display the results of the Negative check for each column
    print(f"Negative Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Negative Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
#Test 4
# Create a Spark session
spark = SparkSession.builder.appName("MaxValuesTest").getOrCreate()

# Load data
data_path = "/content/drive/MyDrive/parquet/unzipped_stocks_2007/content/stocks_2007.parquet"
data_2007 = spark.read.parquet(data_path)

# Use Column Profiler Runner to generate summary statistics
column_profiles = ColumnProfilerRunner(spark) \
    .onData(data_2007) \
    .run()

# Extract maximum values for all numeric columns
max_values = {}

for col_name, profile in column_profiles.profiles.items():
    if profile.dataType == "Integral" or profile.dataType == "Fractional":
        max_values[col_name] = profile.maximum

# Display the maximum values
print("Maximum Values for Numeric Columns:")
for col_name, max_value in max_values.items():
    print(f"{col_name}: {max_value}")
# Out:
# Maximum Values for Numeric Columns:
# open: 62672400384.0
# low: 61613998080.0
# close: 62067601408.0
# volume: 1835338900.0
# adj_close: 62067601408.0
# high: 63503998976.0

# %%
#Test 5
# Assuming the column containing stock tickers is named 'Symbol' in metadata_df_pbd
stock_ticker_col = 'Symbol'

# Extract distinct stock tickers from the metadata
distinct_stock_tickers_metadata = metadata_df_pbd.select(col(stock_ticker_col)).distinct()

# Convert the distinct stock tickers to a list
distinct_tickers_list_metadata = [row[stock_ticker_col] for row in distinct_stock_tickers_metadata.collect()]

# Define a check to verify if stock tickers appear in the metadata
ticker_check = Check(spark, level=CheckLevel.Warning, description="Stock Ticker check") \
    .isContainedIn(stock_ticker_col, distinct_tickers_list_metadata)

# Run the check using the Verification Suite
verification_result = VerificationSuite(spark).onData(metadata_df_pbd).addCheck(ticker_check).run()

# Display the results of the stock ticker check
print("Stock Ticker Check Results:")
print(f"  - Has warnings: {verification_result.status == 'Warning'}")

# Check if there are warnings before trying to access the number of warnings
if 'numRecordsFailed' in verification_result.checkResults[0]:
    print(f"  - Number of warnings: {verification_result.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of warnings: 0")

# Check if 'constraintMessage' is present before accessing it
if 'constraintMessage' in verification_result.checkResults[0]:
    print(f"  - Warning details: {verification_result.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Warning details: No constraint message available\n")
# Out:
# Stock Ticker Check Results:
#   - Has warnings: False
#   - Number of warnings: 0
#   - Warning details: No constraint message available

# %%
#Test 6
# Specify the column to check
col_name = 'date'

# Check for uniqueness in data_2007 based on the 'date' column
unique_check_data_2007_column = Check(spark, level=CheckLevel.Warning, description=f"Uniqueness check for {col_name}") \
    .isUnique(col_name)

# Check for general duplicates in data_2007 for the 'date' column
duplicate_check_data_2007_column = Check(spark, level=CheckLevel.Warning,
                                          description=f"Duplicate check for {col_name}") \
    .hasSize(lambda x: x == data_2007.select(col_name).count(),
             f"Duplicate check for {col_name}")

# Run checks for the 'date' column using the Verification Suite
verification_result_data_2007_column = VerificationSuite(spark) \
    .onData(data_2007) \
    .addCheck(unique_check_data_2007_column) \
    .addCheck(duplicate_check_data_2007_column) \
    .run()

# Display results for the 'date' column
print(f"\nVerification Results for column {col_name} in data_2007:")
print(f"  - Has errors: {verification_result_data_2007_column.status == 'Error'}")
print(f"  - Number of uniqueness errors: {verification_result_data_2007_column.checkResults[0]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_2007_column.checkResults[0] else "0")
print(f"  - Number of duplicate errors: {verification_result_data_2007_column.checkResults[1]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_2007_column.checkResults[1] else "0")
print(f"  - Uniqueness error details: {verification_result_data_2007_column.checkResults[0]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_2007_column.checkResults[0] else "No constraint message available")
print(f"  - Duplicate error details: {verification_result_data_2007_column.checkResults[1]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_2007_column.checkResults[1] else "No constraint message available")

# Print the content of the column with errors
if verification_result_data_2007_column.status == 'Error':
    print(f"  - Content of the column with errors for {col_name}:")
    for check_result in verification_result_data_2007_column.checkResults:
        print(check_result)
# Out:
# Verification Results for column date in data_2007:
#   - Has errors: False
# 0
# 0
# No constraint message available
# No constraint message available

# %%
#Test 6
# 'Symbol' is the column representing stock tickers in metadata_df_pbd
stock_ticker_col_metadata = 'Symbol'

# Check for uniqueness in metadata_df_pbd based on 'Symbol'
unique_check_metadata = Check(spark, level=CheckLevel.Error, description="Uniqueness check for stock tickers") \
    .isUnique(stock_ticker_col_metadata)

# Check for general duplicates in metadata_df_pbd
duplicate_check_metadata = Check(spark, level=CheckLevel.Error, description="Duplicate check for entire metadata") \
    .hasSize(lambda x: x == metadata_df_pbd.count(), "Duplicate check for entire metadata")

# Run both checks using the Verification Suite
verification_result_metadata = VerificationSuite(spark) \
    .onData(metadata_df_pbd) \
    .addCheck(unique_check_metadata) \
    .addCheck(duplicate_check_metadata) \
    .run()

# Display the results of the checks for metadata_df_pbd
print("Verification Results for metadata_df_pbd:")
print(f"  - Has errors: {verification_result_metadata.status == 'Error'}")

# Check if there are errors in the uniqueness check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[0]:
    print(f"  - Number of uniqueness errors: {verification_result_metadata.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of uniqueness errors: 0")

# Check if there are errors in the duplicate check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[1]:
    print(f"  - Number of duplicate errors: {verification_result_metadata.checkResults[1]['numRecordsFailed']}")
else:
    print("  - Number of duplicate errors: 0")

# Check if 'constraintMessage' is present before accessing it for uniqueness check
if 'constraintMessage' in verification_result_metadata.checkResults[0]:
    print(f"  - Uniqueness error details: {verification_result_metadata.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Uniqueness error details: No constraint message available\n")

# Check if 'constraintMessage' is present before accessing it for duplicate check
if 'constraintMessage' in verification_result_metadata.checkResults[1]:
    print(f"  - Duplicate error details: {verification_result_metadata.checkResults[1]['constraintMessage']}\n")
else:
    print("  - Duplicate error details: No constraint message available\n")
# Out:
# Verification Results for metadata_df_pbd:
#   - Has errors: False
#   - Number of uniqueness errors: 0
#   - Number of duplicate errors: 0
#   - Uniqueness error details: No constraint message available
#
#   - Duplicate error details: No constraint message available

# %% [markdown]
# **YEAR 2018**

# %%
#TODO: Write your code here
year = 2018
# Define the data schema with string data types
data_schema = StructType([
    StructField("date", StringType(), True),
    StructField("open", StringType(), True),
    StructField("high", StringType(), True),
    StructField("low", StringType(), True),
    StructField("close", StringType(), True),
    StructField("adj_close", StringType(), True),
    StructField("volume", StringType(), True),
])

# Path to the CSV files for the year 2007
data_path_2018 = "/content/stocks/2018/*/*/*"


# Read in the data for 2018 with the specified schema
data_2018 = spark.read.csv(data_path_2018, schema=data_schema)

# Show the first few rows of the DataFrame
data_2018.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+------------------+----------+
# |      date|              open|              high|               low|             close|         adj_close|    volume|
# +----------+------------------+------------------+------------------+------------------+------------------+----------+
# |      Date|              Open|              High|               Low|             Close|         Adj Close|    Volume|
# |2018-12-18| 68.44999694824219| 69.02999877929689| 67.38999938964844| 67.98999786376953| 67.07752990722656| 2112000.0|
# |2018-12-18|  28.1200008392334| 28.65999984741211| 28.09000015258789|28.239999771118164|28.239999771118164| 2107800.0|
# |2018-12-18|32.470001220703125|33.650001525878906|32.470001220703125|33.540000915527344|33.006290435791016| 9117600.0|
# |2018-12-18| 41.27999877929688|              45.0| 41.27999877929688| 41.58000183105469| 41.58000183105469|    2100.0|
# |2018-12-18| 2.400000095367432|2.4200000762939453|2.3299999237060547|2.4200000762939453|2.4007937908172607|    7100.0|
# |2018-12-18|              42.0|43.560001373291016|  41.5099983215332| 42.95000076293945|  42.7149658203125| 1325200.0|
# |2018-12-18|17.309999465942386| 17.68000030517578|15.140000343322756| 15.40999984741211| 15.40999984741211| 1744800.0|
# |2018-12-18| 34.40999984741211| 35.34000015258789| 34.40999984741211|34.630001068115234| 34.39919662475586|  147600.0|
# |2018-12-18|             160.0|162.88999938964844| 157.8300018310547|158.24000549316406|157.49307250976562| 1312500.0|
# |2018-12-18| 165.3800048828125|167.52999877929688|164.38999938964844|166.07000732421875|  163.224365234375|33841500.0|
# |2018-12-18|              41.0|41.400001525878906|             40.75|41.099998474121094| 39.79087448120117|  297000.0|
# |2018-12-18|0.6299999952316284|0.6299999952316284|0.6000000238418579|0.6000000238418579|0.6000000238418579|  426100.0|
# |2018-12-18| 43.13999938964844|              43.5| 41.97999954223633| 42.11999893188477| 42.11999893188477|  441500.0|
# |2018-12-18| 44.43999862670898| 45.43000030517578| 44.13000106811523|44.459999084472656|44.459999084472656|  735100.0|
# |2018-12-18|25.420000076293945|26.559999465942386|25.420000076293945| 25.78000068664551| 23.25893592834473|  525100.0|
# |2018-12-18|19.540000915527344| 19.63999938964844| 19.34000015258789| 19.40999984741211|17.860050201416016| 3064600.0|
# |2018-12-18| 85.45999908447266|              85.5| 82.80000305175781| 83.58000183105469| 76.92056274414062| 5288600.0|
# |2018-12-18| 77.45999908447266|  78.5999984741211| 75.41999816894531| 76.23999786376953| 74.46778106689453| 1327200.0|
# |2018-12-18| 31.61000061035156|32.450000762939446|31.149999618530273| 32.15999984741211| 31.43630599975586| 1413600.0|
# +----------+------------------+------------------+------------------+------------------+------------------+----------+
# only showing top 20 rows

# %%
import zipfile
# TODO: Replace with the actual path to parquet files
parquet_path = "/content/drive/MyDrive/parquet/stocks_2018.zip"

# Replace "/content/drive/MyDrive/parquet/stocks_2018.zip" with the actual path to zipped Parquet file
zipped_parquet_path = "/content/drive/MyDrive/parquet/stocks_2018.zip"
unzipped_parquet_path = "/content/drive/MyDrive/parquet/unzipped_stocks_2018"

# Create a directory to extract the contents
os.makedirs(unzipped_parquet_path, exist_ok=True)

# Unzip the Parquet file
with zipfile.ZipFile(zipped_parquet_path, 'r') as zip_ref:
    zip_ref.extractall(unzipped_parquet_path)

# List the contents of the Parquet directory
contents = os.listdir('/content/drive/MyDrive/parquet/unzipped_stocks_2018/content/stocks_2018.parquet')
print("Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_2018/content/stocks_2018.parquet:")
for item in contents:
    print(item)
# Out:
# Contents of the /content/drive/MyDrive/parquet/unzipped_stocks_2018/content/stocks_2018.parquet:
# ._SUCCESS.crc
# _SUCCESS
# .part-00000-cffd627a-eddb-4847-938d-16b77028af68-c000.snappy.parquet.crc
# .part-00001-cffd627a-eddb-4847-938d-16b77028af68-c000.snappy.parquet.crc
# part-00001-cffd627a-eddb-4847-938d-16b77028af68-c000.snappy.parquet
# part-00000-cffd627a-eddb-4847-938d-16b77028af68-c000.snappy.parquet

# %%
# Test 1 - Null values using Deequ Verification Suite
# Iterate over columns and perform null check
for col_name in data_2018.columns:
    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Null check for column {col_name}") \
        .isComplete(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_2018).addCheck(check).run()

    # Display the results of the null check for each column
    print(f"Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Null Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column open:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column high:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column low:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Null Values Check for Column volume:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
from pyspark.sql.functions import col

# Drop rows with null values in specific columns
columns_with_nulls = ['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume']
for col_name in columns_with_nulls:
    data_2018 = data_2018.filter(col(col_name).isNotNull())

# Display the count of null values after cleaning
for col_name in columns_with_nulls:
    null_count_after_cleaning = data_2018.where(col(col_name).isNull()).count()
    print(f"After cleaning, Null Values Check for Column {col_name}:")
    print(f"  - Has errors: {null_count_after_cleaning > 0}")
    print(f"  - Number of errors: {null_count_after_cleaning}")
    print("  - Error details: No constraint message available\n")
# Out:
# After cleaning, Null Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Null Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 2 - Zero values using Deequ Verification Suite
for col_name in data_2018.columns:
    # Convert column values to string for Zero check
    data_2018_str = data_2018.withColumn(col_name, F.col(col_name).cast("string"))

    # Define a Check for each column for Zero values
    zero_check = Check(spark, level=CheckLevel.Error, description=f"Zero values check for column {col_name}") \
        .isComplete(col_name)

    # Run Zero check
    zero_result = VerificationSuite(spark).onData(data_2018_str).addCheck(zero_check).run()

    # Display the results of the Zero check for each column
    print(f"Zero Values Check for Column {col_name}:")
    print(f"  - Has errors: {zero_result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in zero_result.checkResults[0]:
        print(f"  - Number of errors: {zero_result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in zero_result.checkResults[0]:
        print(f"  - Error details: {zero_result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Zero Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column open:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column high:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column low:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column adj_close:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Zero Values Check for Column volume:
#   - Has errors: True
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
from pyspark.sql.functions import col

# Drop rows with zero values in specific columns
columns_with_zeros = ['open', 'high', 'low', 'close', 'adj_close', 'volume']
for col_name in columns_with_zeros:
    data_2018 = data_2018.filter(col(col_name) != 0)

# Display the count of zero values after cleaning
for col_name in columns_with_zeros:
    zero_count_after_cleaning = data_2018.where(col(col_name) == 0).count()
    print(f"After cleaning, Zero Values Check for Column {col_name}:")
    print(f"  - Has errors: {zero_count_after_cleaning > 0}")
    print(f"  - Number of errors: {zero_count_after_cleaning}")
    print("  - Error details: No constraint message available\n")
# Out:
# After cleaning, Zero Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# After cleaning, Zero Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
# Test 3 - Negative values using Deequ Verification Suite
table_negative_values = []

for col_name in data_2018.columns:
    # Convert column values to string
    data_2018_str = data_2018.withColumn(col_name, col(col_name).cast("string"))

    # Define a Check for each column
    check = Check(spark, level=CheckLevel.Error, description=f"Negative check for column {col_name}") \
        .isNonNegative(col_name)

    # Add the check to the Verification Suite
    result = VerificationSuite(spark).onData(data_2018_str).addCheck(check).run()

    # Display the results of the Negative check for each column
    print(f"Negative Values Check for Column {col_name}:")
    print(f"  - Has errors: {result.status == 'Error'}")

    # Check if there are errors before trying to access the number of errors
    if 'numRecordsFailed' in result.checkResults[0]:
        print(f"  - Number of errors: {result.checkResults[0]['numRecordsFailed']}")
    else:
        print("  - Number of errors: 0")

    # Check if 'constraintMessage' is present before accessing it
    if 'constraintMessage' in result.checkResults[0]:
        print(f"  - Error details: {result.checkResults[0]['constraintMessage']}\n")
    else:
        print("  - Error details: No constraint message available\n")
# Out:
# Negative Values Check for Column date:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column open:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column high:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column low:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column adj_close:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available
#
# Negative Values Check for Column volume:
#   - Has errors: False
#   - Number of errors: 0
#   - Error details: No constraint message available

# %%
#Test 4
# Create a Spark session
spark = SparkSession.builder.appName("MaxValuesTest").getOrCreate()

# Load data
data_path = "/content/drive/MyDrive/parquet/unzipped_stocks_2018/content/stocks_2018.parquet"
data_2018 = spark.read.parquet(data_path)

# Use Column Profiler Runner to generate summary statistics
column_profiles = ColumnProfilerRunner(spark) \
    .onData(data_2018) \
    .run()

# Extract maximum values for all numeric columns
max_values = {}

for col_name, profile in column_profiles.profiles.items():
    if profile.dataType == "Integral" or profile.dataType == "Fractional":
        max_values[col_name] = profile.maximum

# Display the maximum values
print("Maximum Values for Numeric Columns:")
for col_name, max_value in max_values.items():
    print(f"{col_name}: {max_value}")
# Out:
# Maximum Values for Numeric Columns:
# open: 117187.5
# low: 109375.0
# close: 109375.0
# volume: 358775700.0
# adj_close: 109375.0
# high: 125000.0

# %%
#Test 5
# Assuming the column containing stock tickers is named 'Symbol' in metadata_df_pbd
stock_ticker_col = 'Symbol'

# Extract distinct stock tickers from the metadata
distinct_stock_tickers_metadata = metadata_df_pbd.select(col(stock_ticker_col)).distinct()

# Convert the distinct stock tickers to a list
distinct_tickers_list_metadata = [row[stock_ticker_col] for row in distinct_stock_tickers_metadata.collect()]

# Define a check to verify if stock tickers appear in the metadata
ticker_check = Check(spark, level=CheckLevel.Warning, description="Stock Ticker check") \
    .isContainedIn(stock_ticker_col, distinct_tickers_list_metadata)

# Run the check using the Verification Suite
verification_result = VerificationSuite(spark).onData(metadata_df_pbd).addCheck(ticker_check).run()

# Display the results of the stock ticker check
print("Stock Ticker Check Results:")
print(f"  - Has warnings: {verification_result.status == 'Warning'}")

# Check if there are warnings before trying to access the number of warnings
if 'numRecordsFailed' in verification_result.checkResults[0]:
    print(f"  - Number of warnings: {verification_result.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of warnings: 0")

# Check if 'constraintMessage' is present before accessing it
if 'constraintMessage' in verification_result.checkResults[0]:
    print(f"  - Warning details: {verification_result.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Warning details: No constraint message available\n")
# Out:
# Stock Ticker Check Results:
#   - Has warnings: False
#   - Number of warnings: 0
#   - Warning details: No constraint message available

# %%
#Test 6
# Specify the column to check
col_name = 'date'

# Check for uniqueness in data_2007 based on the 'date' column
unique_check_data_2018_column = Check(spark, level=CheckLevel.Warning, description=f"Uniqueness check for {col_name}") \
    .isUnique(col_name)

# Check for general duplicates in data_2007 for the 'date' column
duplicate_check_data_2018_column = Check(spark, level=CheckLevel.Warning,
                                          description=f"Duplicate check for {col_name}") \
    .hasSize(lambda x: x == data_2018.select(col_name).count(),
             f"Duplicate check for {col_name}")

# Run checks for the 'date' column using the Verification Suite
verification_result_data_2018_column = VerificationSuite(spark) \
    .onData(data_2018) \
    .addCheck(unique_check_data_2018_column) \
    .addCheck(duplicate_check_data_2018_column) \
    .run()

# Display results for the 'date' column
print(f"\nVerification Results for column {col_name} in data_2018:")
print(f"  - Has errors: {verification_result_data_2018_column.status == 'Error'}")
print(f"  - Number of uniqueness errors: {verification_result_data_2018_column.checkResults[0]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_2018_column.checkResults[0] else "0")
print(f"  - Number of duplicate errors: {verification_result_data_2018_column.checkResults[1]['numRecordsFailed']}"
      if 'numRecordsFailed' in verification_result_data_2018_column.checkResults[1] else "0")
print(f"  - Uniqueness error details: {verification_result_data_2018_column.checkResults[0]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_2018_column.checkResults[0] else "No constraint message available")
print(f"  - Duplicate error details: {verification_result_data_2018_column.checkResults[1]['constraintMessage']}"
      if 'constraintMessage' in verification_result_data_2018_column.checkResults[1] else "No constraint message available")

# Print the content of the column with errors
if verification_result_data_2018_column.status == 'Error':
    print(f"  - Content of the column with errors for {col_name}:")
    for check_result in verification_result_data_2018_column.checkResults:
        print(check_result)
# Out:
# Verification Results for column date in data_2018:
#   - Has errors: False
# 0
# 0
# No constraint message available
# No constraint message available

# %%
#Test 6
# 'Symbol' is the column representing stock tickers in metadata_df_pbd
stock_ticker_col_metadata = 'Symbol'

# Check for uniqueness in metadata_df_pbd based on 'Symbol'
unique_check_metadata = Check(spark, level=CheckLevel.Error, description="Uniqueness check for stock tickers") \
    .isUnique(stock_ticker_col_metadata)

# Check for general duplicates in metadata_df_pbd
duplicate_check_metadata = Check(spark, level=CheckLevel.Error, description="Duplicate check for entire metadata") \
    .hasSize(lambda x: x == metadata_df_pbd.count(), "Duplicate check for entire metadata")

# Run both checks using the Verification Suite
verification_result_metadata = VerificationSuite(spark) \
    .onData(metadata_df_pbd) \
    .addCheck(unique_check_metadata) \
    .addCheck(duplicate_check_metadata) \
    .run()

# Display the results of the checks for metadata_df_pbd
print("Verification Results for metadata_df_pbd:")
print(f"  - Has errors: {verification_result_metadata.status == 'Error'}")

# Check if there are errors in the uniqueness check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[0]:
    print(f"  - Number of uniqueness errors: {verification_result_metadata.checkResults[0]['numRecordsFailed']}")
else:
    print("  - Number of uniqueness errors: 0")

# Check if there are errors in the duplicate check before trying to access the number of errors
if 'numRecordsFailed' in verification_result_metadata.checkResults[1]:
    print(f"  - Number of duplicate errors: {verification_result_metadata.checkResults[1]['numRecordsFailed']}")
else:
    print("  - Number of duplicate errors: 0")

# Check if 'constraintMessage' is present before accessing it for uniqueness check
if 'constraintMessage' in verification_result_metadata.checkResults[0]:
    print(f"  - Uniqueness error details: {verification_result_metadata.checkResults[0]['constraintMessage']}\n")
else:
    print("  - Uniqueness error details: No constraint message available\n")

# Check if 'constraintMessage' is present before accessing it for duplicate check
if 'constraintMessage' in verification_result_metadata.checkResults[1]:
    print(f"  - Duplicate error details: {verification_result_metadata.checkResults[1]['constraintMessage']}\n")
else:
    print("  - Duplicate error details: No constraint message available\n")
# Out:
# Verification Results for metadata_df_pbd:
#   - Has errors: False
#   - Number of uniqueness errors: 0
#   - Number of duplicate errors: 0
#   - Uniqueness error details: No constraint message available
#
#   - Duplicate error details: No constraint message available
